# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer, OneHotEncoder
from sklearn_pandas import DataFrameMapper
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.tree import export_graphviz
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 模型的apply函数

# %%
application_train = pd.read_csv('data/application_train.csv')

X = application_train[[col for col in application_train.columns if col not in ['SK_ID_CURR', 'TARGET', 'DATE']]]
y = application_train['TARGET']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

col_types = X_train.dtypes
char_cols = list(col_types[col_types == 'object'].index)
num_cols = list(col_types[col_types != 'object'].index)

# GradientBoostingClassifier不支持缺失，填充缺失
X_train[char_cols] = X_train[char_cols].fillna('null')
X_train[num_cols] = X_train[num_cols].fillna(-1)
X_test[char_cols] = X_test[char_cols].fillna('null')
X_test[num_cols] = X_test[num_cols].fillna(-1)

# GradientBoostingClassifier不支持类别特征，对类别特征进行ont-hot编码，并使测试集与训练集编码后的特征保持一致
X_train_new = X_train[num_cols].join(pd.get_dummies(X_train[char_cols]))
X_test_new = X_test[num_cols].join(pd.get_dummies(X_test[char_cols]))

for col in set(X_train_new.columns) - set(X_test_new.columns):
    X_test_new[col] = 0
X_test_new = X_test_new[X_train_new.columns]

# 训练模型
model = GradientBoostingClassifier(random_state=1234)
model.fit(X_train_new, y_train)

# 获取落到每颗子树的叶子节点结果
train_leaf_feature1 = model.apply(X_train_new)[:, :, 0]
test_leaf_feature1 = model.apply(X_test_new)[:, :, 0]

# 转换成GBDT特征
enc = OneHotEncoder()
enc.fit(train_leaf_feature1)
train_gbdt_feature1 = np.array(enc.transform(train_leaf_feature1).toarray())
test_gbdt_feature1 = np.array(enc.transform(test_leaf_feature1).toarray())

# %%
train_leaf_feature1
# Out:
# array([[13., 13., 13., ...,  3.,  4., 14.],
#        [13., 14., 14., ...,  6.,  3., 14.],
#        [10., 10., 11., ...,  3.,  4., 14.],
#        ...,
#        [13., 13., 13., ..., 11.,  4., 14.],
#        [ 6.,  7.,  7., ...,  3.,  4., 14.],
#        [ 4.,  4., 10., ..., 10.,  4., 14.]])

# %%
train_leaf_feature1.shape
# Out:
# (43051, 100)

# %%
import graphviz
dot_data = export_graphviz(model.estimators_[0, 0], out_file=None, feature_names=X_train_new.columns,
                           filled=True, rounded=True, special_characters=True)
graph = graphviz.Source(dot_data)
graph.render('tree1.gv')
# Out:
# 'tree1.gv.pdf'

# %%
set(train_leaf_feature1[:, 0])
# Out:
# {3.0, 4.0, 6.0, 7.0, 10.0, 11.0, 13.0, 14.0}

# %%
X_train.iloc[0][['EXT_SOURCE_2', 'EXT_SOURCE_3']]
# Out:
# EXT_SOURCE_2    0.447966
# EXT_SOURCE_3     0.58674
# Name: 53107, dtype: object

# %%
train_gbdt_feature1[0, :8]
# Out:
# array([0., 0., 0., 0., 0., 0., 1., 0.])

# %% [markdown]
# ## 解析树结构

# %%
export_graphviz(model.estimators_[0, 0], feature_names=X_train_new.columns, precision=6).split('\n')
# Out:
# ['digraph Tree {',
#  'node [shape=box] ;',
#  '0 [label="EXT_SOURCE_2 <= 0.356838\\nfriedman_mse = 0.074066\\nsamples = 43051\\nvalue = 0.0"] ;',
#  '1 [label="EXT_SOURCE_3 <= 0.36813\\nfriedman_mse = 0.127764\\nsamples = 9423\\nvalue = 0.069821"] ;',
#  '0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;',
#  '2 [label="EXT_SOURCE_2 <= 0.108422\\nfriedman_mse = 0.165696\\nsamples = 4436\\nvalue = 0.129093"] ;',
#  '1 -> 2 ;',
#  '3 [label="friedman_mse = 0.213775\\nsamples = 972\\nvalue = 3.093375"] ;',
#  '2 -> 3 ;',
#  '4 [label="friedman_mse = 0.14861\\nsamples = 3464\\nvalue = 1.363997"] ;',
#  '2 -> 4 ;',
#  '5 [label="EXT_SOURCE_2 <= 0.137969\\nfriedman_mse = 0.088118\\nsamples = 4987\\nvalue = 0.017098"] ;',
#  '1 -> 5 ;',
#  '6 [label="friedman_mse = 0.124332\\nsamples = 1134\\nvalue = 0.876876"] ;',
#  '5 -> 6 ;',
#  '7 [label="friedman_mse = 0.076587\\nsamples = 3853\\nvalue = 0.040715"] ;',
#  '5 -> 7 ;',
#  '8 [label="EXT_SOURCE_3 <= 0.42325\\nfriedman_mse = 0.057271\\nsamples = 33628\\nvalue = -0.019565"] ;',
#  '0 -> 8 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;',
#  '9 [label="EXT_SOURCE_2 <= 0.597194\\nfriedman_mse = 0.08391\\nsamples = 14666\\nvalue = 0.011903"] ;',
#  '8 -> 9 ;',
#  '10 [label="friedman_mse = 0.105441\\nsamples = 7079\\nvalue = 0.529731"] ;',
#  '9 -> 10 ;',
#  '11 [label="friedman_mse = 0.062473\\nsamples = 7587\\nvalue = -0.183605"] ;',
#  '9 -> 11 ;',
#  '12 [label="EXT_SOURCE_2 <= 0.623373\\nfriedman_mse = 0.035309\\nsamples = 18962\\nvalue = -0.043903"] ;',
#  '8 -> 12 ;',
#  '13 [label="friedman_mse = 0.044665\\nsamples = 9731\\nvalue = -0.454931"] ;',
#  '12 -> 13 ;',
#  '14 [label="friedman_mse = 0.025221\\nsamples = 9231\\nvalue = -0.738048"] ;',
#  '12 -> 14 ;',
#  '}']

# %%
now_col = 'NAME_TYPE_SUITE_Other_A'
char_col = 'NAME_TYPE_SUITE'

# %%
def get_gbdt_path(model, data_cols, char_cols=[], precision=6):
    '''
    根据数据集和GBDT模型,输出按照GBDT的路径衍生的变量:
    ------------------------------------------------------------
    入参结果如下:
        model: 训练完的GBDT模型
        data_cols: 训练数据集的特征列表
        char_cols: 类别特征的特征列表
            由于类别特征需one-hot编码后进模型,在树结构中会出现var_value > 0.5的节点,传入char_cols则可以将节点改为var ==/!= value
        precision: 提取每个子树的文字结构时,内部节点判断阈值的精确小数位，保留位数太少可能存在误差
    ------------------------------------------------------------
    出参结果如下:
        gbdt_path: GBDT所有叶子节点经过的路径
    '''
    # 类别特征节点判断转换的字段
    if isinstance(char_cols, list) and char_cols != []:
        node_judge_trans = {}
        for char_col in char_cols:
            for now_col in data_cols:
                if char_col in now_col:
                    node_judge_trans['{} > 0.5'.format(now_col)] = '{} == {}'.format(char_col, now_col.replace(char_col + '_', ''))
                    node_judge_trans['{} <= 0.5'.format(now_col)] = '{} != {}'.format(char_col, now_col.replace(char_col + '_', ''))
    
    # 所有树的叶子节点路径
    leaf_node_path = []
    # 遍历每棵子树
    for n in range(model.n_estimators_):
        tree_text = export_graphviz(model.estimators_[n, 0], feature_names=data_cols, precision=precision)

        # 节点
        node = {}
        # 叶子节点
        leaf_node_index = []
        # 节点经过的路径
        node_path = {}
        # 分裂的节点
        split_node = []

        # 遍历每颗子树内部情况
        for line in tree_text.split('\n'):
            # 获取现节点的索引
            if '[label=' in line:
                node_index = int(line[: line.find('[') - 1])
                # 如果现节点有条件判断，保存判断
                if 'label="friedman_mse' not in line:
                    node[node_index] = line[line.find('label="') + 7: line.find('\\nfriedman_mse')]
                else:
                    leaf_node_index.append(node_index)

            # 上一个节点到下一个节点的路径
            if '->' in line:
                # 获取上一个节点的索引
                previous_node_index = int(line[: line.find('->') - 1])
                # 获取下一个节点的索引
                if '[' in line:
                    next_node_index = int(line[line.find('->') + 3: line.find('[') - 1])
                else:
                    next_node_index = int(line[line.find('->') + 3: line.find(';') - 1])

                # 分裂的左路径
                if previous_node_index not in split_node:
                    split_node.append(previous_node_index)
                    # 从根节点到现节点的路径
                    if previous_node_index == 0:
                        node_path[next_node_index] = node[previous_node_index]
                    else:
                        node_path[next_node_index] = (node_path[previous_node_index] + ' & ' + node[previous_node_index])
                # 分裂的右路径
                else:
                    # 从根节点到现节点的路径
                    if previous_node_index == 0:
                        node_path[next_node_index] = node[previous_node_index].replace('<=', '>')
                    else:
                        node_path[next_node_index] = (node_path[previous_node_index] + ' & ' + node[previous_node_index].replace('<=', '>'))
                        
        if isinstance(char_cols, list) and char_cols != []:
            # 遍历刚才生成的每个节点对应路径的字典
            for index in node_path.keys():
                # 由于类别特征会进行one-hot编码,导致节点的判断为<=0.5/>0.5,将其替换成未one-hot编码前的表达方式var ==/!= value
                for old_judge, new_judge in node_judge_trans.items():
                    node_path[index] = node_path[index].replace(old_judge, new_judge)

        leaf_node_path += [value for key, value in node_path.items() if key in leaf_node_index]
    
    gbdt_path = {index + 1: value for index, value in enumerate(leaf_node_path)}
    
    return gbdt_path

# %%
data_cols = X_train_new.columns
gbdt_path = get_gbdt_path(model, data_cols, char_cols, precision=6)

# %%
print('模型的apply函数方法提取的GBDT特征数：', train_gbdt_feature1.shape[1])
print('解析树结构方法提取的GBDT路径数：', len(gbdt_path))
# Out:
# 模型的apply函数方法提取的GBDT特征数： 773
# 解析树结构方法提取的GBDT路径数： 773

# %%
gbdt_path
# Out:
# {1: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.36813 & EXT_SOURCE_2 <= 0.108422',
#  2: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.36813 & EXT_SOURCE_2 > 0.108422',
#  3: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 > 0.36813 & EXT_SOURCE_2 <= 0.137969',
#  4: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 > 0.36813 & EXT_SOURCE_2 > 0.137969',
#  5: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 <= 0.42325 & EXT_SOURCE_2 <= 0.597194',
#  6: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 <= 0.42325 & EXT_SOURCE_2 > 0.597194',
#  7: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 > 0.42325 & EXT_SOURCE_2 <= 0.623373',
#  8: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 > 0.42325 & EXT_SOURCE_2 > 0.623373',
#  9: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.373177 & EXT_SOURCE_2 <= 0.106543',
#  10: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.373177 & EXT_SOURCE_2 > 0.106543',
#  11: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 > 0.373177 & EXT_SOURCE_3 <= 0.5718',
#  12: 'EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 > 0.373177 & EXT_SOURCE_3 > 0.5718',
#  13: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 <= 0.42325 & EXT_SOURCE_2 <= 0.591941',
#  14: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 <= 0.42325 & EXT_SOURCE_2 > 0.591941',
#  15: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 > 0.42325 & EXT_SOURCE_2 <= 0.587942',
#  16: 'EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 > 0.42325 & EXT_SOURCE_2 > 0.587942',
#  17: 'EXT_SOURCE_2 <= 0.247911 & EXT_SOURCE_3 <= 0.264348 & EXT_SOURCE_3 <= -0.499736',
#  18: 'EXT_SOURCE_2 <= 0.247911 & EXT_SOURCE_3 <= 0.264348 & EXT_SOURCE_3 > -0.499736',
#  19: 'EXT_SOURCE_2 <= 0.247911 & EXT_SOURCE_3 > 0.264348 & DAYS_BIRTH <= -19891.5',
#  20: 'EXT_SOURCE_2 <= 0.247911 & EXT_SOURCE_3 > 0.264348 & DAYS_BIRTH > -19891.5',
#  21: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.425012 & EXT_SOURCE_2 <= 0.480754',
#  22: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.425012 & EXT_SOURCE_2 > 0.480754',
#  23: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 > 0.425012 & EXT_SOURCE_2 <= 0.55862',
#  24: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 > 0.425012 & EXT_SOURCE_2 > 0.55862',
#  25: 'EXT_SOURCE_2 <= 0.392158 & EXT_SOURCE_3 <= 0.400542 & EXT_SOURCE_2 <= 0.168078',
#  26: 'EXT_SOURCE_2 <= 0.392158 & EXT_SOURCE_3 <= 0.400542 & EXT_SOURCE_2 > 0.168078',
#  27: 'EXT_SOURCE_2 <= 0.392158 & EXT_SOURCE_3 > 0.400542 & CODE_GENDER != M',
#  28: 'EXT_SOURCE_2 <= 0.392158 & EXT_SOURCE_3 > 0.400542 & CODE_GENDER == M',
#  29: 'EXT_SOURCE_2 > 0.392158 & EXT_SOURCE_3 <= 0.390197 & EXT_SOURCE_3 <= -0.499736',
#  30: 'EXT_SOURCE_2 > 0.392158 & EXT_SOURCE_3 <= 0.390197 & EXT_SOURCE_3 > -0.499736',
#  31: 'EXT_SOURCE_2 > 0.392158 & EXT_SOURCE_3 > 0.390197 & EXT_SOURCE_3 <= 0.623768',
#  32: 'EXT_SOURCE_2 > 0.392158 & EXT_SOURCE_3 > 0.390197 & EXT_SOURCE_3 > 0.623768',
#  33: 'EXT_SOURCE_2 <= 0.462132 & EXT_SOURCE_3 <= 0.474951 & EXT_SOURCE_2 <= 0.168078',
#  34: 'EXT_SOURCE_2 <= 0.462132 & EXT_SOURCE_3 <= 0.474951 & EXT_SOURCE_2 > 0.168078',
#  35: 'EXT_SOURCE_2 <= 0.462132 & EXT_SOURCE_3 > 0.474951 & EXT_SOURCE_2 <= 0.065932',
#  36: 'EXT_SOURCE_2 <= 0.462132 & EXT_SOURCE_3 > 0.474951 & EXT_SOURCE_2 > 0.065932',
#  37: 'EXT_SOURCE_2 > 0.462132 & EXT_SOURCE_3 <= 0.390197 & EXT_SOURCE_3 <= -0.499736',
#  38: 'EXT_SOURCE_2 > 0.462132 & EXT_SOURCE_3 <= 0.390197 & EXT_SOURCE_3 > -0.499736',
#  39: 'EXT_SOURCE_2 > 0.462132 & EXT_SOURCE_3 > 0.390197 & CODE_GENDER != M',
#  40: 'EXT_SOURCE_2 > 0.462132 & EXT_SOURCE_3 > 0.390197 & CODE_GENDER == M',
#  41: 'EXT_SOURCE_2 <= 0.247911 & NAME_INCOME_TYPE != Working & NAME_INCOME_TYPE != Commercial associate',
#  42: 'EXT_SOURCE_2 <= 0.247911 & NAME_INCOME_TYPE != Working & NAME_INCOME_TYPE == Commercial associate',
#  43: 'EXT_SOURCE_2 <= 0.247911 & NAME_INCOME_TYPE == Working & EXT_SOURCE_3 <= 0.260162',
#  44: 'EXT_SOURCE_2 <= 0.247911 & NAME_INCOME_TYPE == Working & EXT_SOURCE_3 > 0.260162',
#  45: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.425012 & EXT_SOURCE_2 <= 0.591941',
#  46: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.425012 & EXT_SOURCE_2 > 0.591941',
#  47: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 > 0.425012 & EXT_SOURCE_1 <= 0.580525',
#  48: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 > 0.425012 & EXT_SOURCE_1 > 0.580525',
#  49: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 <= 0.317814 & EXT_SOURCE_3 <= -0.499736',
#  50: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 <= 0.317814 & EXT_SOURCE_3 > -0.499736',
#  51: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 > 0.317814 & EXT_SOURCE_1 <= 0.423917',
#  52: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 > 0.317814 & EXT_SOURCE_1 > 0.423917',
#  53: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_3 <= 0.390197 & EXT_SOURCE_3 <= -0.499736',
#  54: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_3 <= 0.390197 & EXT_SOURCE_3 > -0.499736',
#  55: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_3 > 0.390197 & CODE_GENDER != M',
#  56: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_3 > 0.390197 & CODE_GENDER == M',
#  57: 'EXT_SOURCE_2 <= 0.170427 & EXT_SOURCE_3 <= 0.245184 & EXT_SOURCE_3 <= -0.499736',
#  58: 'EXT_SOURCE_2 <= 0.170427 & EXT_SOURCE_3 <= 0.245184 & EXT_SOURCE_3 > -0.499736',
#  59: 'EXT_SOURCE_2 <= 0.170427 & EXT_SOURCE_3 > 0.245184 & EXT_SOURCE_3 <= 0.730277',
#  60: 'EXT_SOURCE_2 <= 0.170427 & EXT_SOURCE_3 > 0.245184 & EXT_SOURCE_3 > 0.730277',
#  61: 'EXT_SOURCE_2 > 0.170427 & EXT_SOURCE_3 <= 0.343342 & EXT_SOURCE_3 <= -0.499736',
#  62: 'EXT_SOURCE_2 > 0.170427 & EXT_SOURCE_3 <= 0.343342 & EXT_SOURCE_3 > -0.499736',
#  63: 'EXT_SOURCE_2 > 0.170427 & EXT_SOURCE_3 > 0.343342 & EXT_SOURCE_1 <= 0.514937',
#  64: 'EXT_SOURCE_2 > 0.170427 & EXT_SOURCE_3 > 0.343342 & EXT_SOURCE_1 > 0.514937',
#  65: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 <= 0.474951 & EXT_SOURCE_1 <= 0.425951',
#  66: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 <= 0.474951 & EXT_SOURCE_1 > 0.425951',
#  67: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 > 0.474951 & DAYS_BIRTH <= -13077.5',
#  68: 'EXT_SOURCE_2 <= 0.483946 & EXT_SOURCE_3 > 0.474951 & DAYS_BIRTH > -13077.5',
#  69: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_2 <= 0.653372 & EXT_SOURCE_3 <= 0.328859',
#  70: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_2 <= 0.653372 & EXT_SOURCE_3 > 0.328859',
#  71: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_2 > 0.653372 & EXT_SOURCE_1 <= 0.652162',
#  72: 'EXT_SOURCE_2 > 0.483946 & EXT_SOURCE_2 > 0.653372 & EXT_SOURCE_1 > 0.652162',
#  73: 'EXT_SOURCE_2 <= 0.152829 & NAME_INCOME_TYPE != Working & ORGANIZATION_TYPE != Business Entity Type 2',
#  74: 'EXT_SOURCE_2 <= 0.152829 & NAME_INCOME_TYPE != Working & ORGANIZATION_TYPE == Business Entity Type 2',
#  75: 'EXT_SOURCE_2 <= 0.152829 & NAME_INCOME_TYPE == Working & DAYS_ID_PUBLISH <= -797.0',
#  76: 'EXT_SOURCE_2 <= 0.152829 & NAME_INCOME_TYPE == Working & DAYS_ID_PUBLISH > -797.0',
#  77: 'EXT_SOURCE_2 > 0.152829 & EXT_SOURCE_3 <= 0.510991 & EXT_SOURCE_1 <= 0.425923',
#  78: 'EXT_SOURCE_2 > 0.152829 & EXT_SOURCE_3 <= 0.510991 & EXT_SOURCE_1 > 0.425923',
#  79: 'EXT_SOURCE_2 > 0.152829 & EXT_SOURCE_3 > 0.510991 & DAYS_BIRTH <= -13923.0',
#  80: 'EXT_SOURCE_2 > 0.152829 & EXT_SOURCE_3 > 0.510991 & DAYS_BIRTH > -13923.0',
#  81: 'EXT_SOURCE_2 <= 0.55861 & EXT_SOURCE_3 <= 0.264348 & EXT_SOURCE_3 <= -0.499736',
#  82: 'EXT_SOURCE_2 <= 0.55861 & EXT_SOURCE_3 <= 0.264348 & EXT_SOURCE_3 > -0.499736',
#  83: 'EXT_SOURCE_2 <= 0.55861 & EXT_SOURCE_3 > 0.264348 & NAME_INCOME_TYPE != Working',
#  84: 'EXT_SOURCE_2 <= 0.55861 & EXT_SOURCE_3 > 0.264348 & NAME_INCOME_TYPE == Working',
#  85: 'EXT_SOURCE_2 > 0.55861 & EXT_SOURCE_2 <= 0.71894 & EXT_SOURCE_3 <= 0.371492',
#  86: 'EXT_SOURCE_2 > 0.55861 & EXT_SOURCE_2 <= 0.71894 & EXT_SOURCE_3 > 0.371492',
#  87: 'EXT_SOURCE_2 > 0.55861 & EXT_SOURCE_2 > 0.71894 & NAME_TYPE_SUITE != Family',
#  88: 'EXT_SOURCE_2 > 0.55861 & EXT_SOURCE_2 > 0.71894 & NAME_TYPE_SUITE == Family',
#  89: 'EXT_SOURCE_2 <= 0.247911 & AMT_CREDIT <= 260682.75 & DAYS_BIRTH <= -19519.5',
#  90: 'EXT_SOURCE_2 <= 0.247911 & AMT_CREDIT <= 260682.75 & DAYS_BIRTH > -19519.5',
#  91: 'EXT_SOURCE_2 <= 0.247911 & AMT_CREDIT > 260682.75 & AMT_GOODS_PRICE <= 452250.0',
#  92: 'EXT_SOURCE_2 <= 0.247911 & AMT_CREDIT > 260682.75 & AMT_GOODS_PRICE > 452250.0',
#  93: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.514595 & EXT_SOURCE_1 <= 0.425923',
#  94: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.514595 & EXT_SOURCE_1 > 0.425923',
#  95: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 > 0.514595 & NAME_EDUCATION_TYPE != Higher education',
#  96: 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 > 0.514595 & NAME_EDUCATION_TYPE == Higher education',
#  97: 'EXT_SOURCE_2 <= 0.59197 & EXT_SOURCE_3 <= 0.516396 & EXT_SOURCE_1 <= 0.425929',
#  98: 'EXT_SOURCE_2 <= 0.59197 & EXT_SOURCE_3 <= 0.516396 & EXT_SOURCE_1 > 0.425929',
#  99: 'EXT_SOURCE_2 <= 0.59197 & EXT_SOURCE_3 > 0.516396 & DAYS_BIRTH <= -17505.5',
#  100: 'EXT_SOURCE_2 <= 0.59197 & EXT_SOURCE_3 > 0.516396 & DAYS_BIRTH > -17505.5',
#  101: 'EXT_SOURCE_2 > 0.59197 & CODE_GENDER != F & EXT_SOURCE_3 <= 0.554056',
#  102: 'EXT_SOURCE_2 > 0.59197 & CODE_GENDER != F & EXT_SOURCE_3 > 0.554056',
#  103: 'EXT_SOURCE_2 > 0.59197 & CODE_GENDER == F & HOUR_APPR_PROCESS_START <= 0.5',
#  104: 'EXT_SOURCE_2 > 0.59197 & CODE_GENDER == F & HOUR_APPR_PROCESS_START > 0.5',
#  105: 'NAME_INCOME_TYPE != Working & FLAG_DOCUMENT_3 <= 0.5 & AMT_REQ_CREDIT_BUREAU_WEEK <= 3.5',
#  106: 'NAME_INCOME_TYPE != Working & FLAG_DOCUMENT_3 <= 0.5 & AMT_REQ_CREDIT_BUREAU_WEEK > 3.5',
#  107: 'NAME_INCOME_TYPE != Working & FLAG_DOCUMENT_3 > 0.5 & DAYS_BIRTH <= -13624.0',
#  108: 'NAME_INCOME_TYPE != Working & FLAG_DOCUMENT_3 > 0.5 & DAYS_BIRTH > -13624.0',
#  109: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_2 <= 0.126081 & DAYS_ID_PUBLISH <= -797.5',
#  110: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_2 <= 0.126081 & DAYS_ID_PUBLISH > -797.5',
#  111: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_2 > 0.126081 & EXT_SOURCE_3 <= 0.512793',
#  112: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_2 > 0.126081 & EXT_SOURCE_3 > 0.512793',
#  113: 'EXT_SOURCE_2 <= 0.623427 & EXT_SOURCE_3 <= 0.265753 & EXT_SOURCE_3 <= -0.499736',
#  114: 'EXT_SOURCE_2 <= 0.623427 & EXT_SOURCE_3 <= 0.265753 & EXT_SOURCE_3 > -0.499736',
#  115: 'EXT_SOURCE_2 <= 0.623427 & EXT_SOURCE_3 > 0.265753 & TOTALAREA_MODE <= 0.04005',
#  116: 'EXT_SOURCE_2 <= 0.623427 & EXT_SOURCE_3 > 0.265753 & TOTALAREA_MODE > 0.04005',
#  117: 'EXT_SOURCE_2 > 0.623427 & OCCUPATION_TYPE != Drivers & EXT_SOURCE_1 <= 0.652162',
#  118: 'EXT_SOURCE_2 > 0.623427 & OCCUPATION_TYPE != Drivers & EXT_SOURCE_1 > 0.652162',
#  119: 'EXT_SOURCE_2 > 0.623427 & OCCUPATION_TYPE == Drivers & HOUR_APPR_PROCESS_START <= 1.5',
#  120: 'EXT_SOURCE_2 > 0.623427 & OCCUPATION_TYPE == Drivers & HOUR_APPR_PROCESS_START > 1.5',
#  121: 'NAME_EDUCATION_TYPE != Higher education & DAYS_BIRTH <= -19578.5 & AMT_ANNUITY <= 24234.75',
#  122: 'NAME_EDUCATION_TYPE != Higher education & DAYS_BIRTH <= -19578.5 & AMT_ANNUITY > 24234.75',
#  123: 'NAME_EDUCATION_TYPE != Higher education & DAYS_BIRTH > -19578.5 & EXT_SOURCE_1 <= 0.423253',
#  124: 'NAME_EDUCATION_TYPE != Higher education & DAYS_BIRTH > -19578.5 & EXT_SOURCE_1 > 0.423253',
#  125: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 <= 0.204558 & OCCUPATION_TYPE != Waiters/barmen staff',
#  126: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 <= 0.204558 & OCCUPATION_TYPE == Waiters/barmen staff',
#  127: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 > 0.204558 & FLAG_DOCUMENT_2 <= 0.5',
#  128: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 > 0.204558 & FLAG_DOCUMENT_2 > 0.5',
#  129: 'EXT_SOURCE_2 <= 0.07613 & WALLSMATERIAL_MODE != Wooden & DAYS_REGISTRATION <= -2705.5',
#  130: 'EXT_SOURCE_2 <= 0.07613 & WALLSMATERIAL_MODE != Wooden & DAYS_REGISTRATION > -2705.5',
#  131: 'EXT_SOURCE_2 <= 0.07613 & WALLSMATERIAL_MODE == Wooden & APARTMENTS_MODE <= 0.00945',
#  132: 'EXT_SOURCE_2 <= 0.07613 & WALLSMATERIAL_MODE == Wooden & APARTMENTS_MODE > 0.00945',
#  133: 'EXT_SOURCE_2 > 0.07613 & CODE_GENDER != M & TOTALAREA_MODE <= 0.02155',
#  134: 'EXT_SOURCE_2 > 0.07613 & CODE_GENDER != M & TOTALAREA_MODE > 0.02155',
#  135: 'EXT_SOURCE_2 > 0.07613 & CODE_GENDER == M & FLAG_OWN_CAR != Y',
#  136: 'EXT_SOURCE_2 > 0.07613 & CODE_GENDER == M & FLAG_OWN_CAR == Y',
#  137: 'NAME_INCOME_TYPE != Working & REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE != Commercial associate',
#  138: 'NAME_INCOME_TYPE != Working & REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE == Commercial associate',
#  139: 'NAME_INCOME_TYPE != Working & REGION_RATING_CLIENT_W_CITY > 2.5 & ORGANIZATION_TYPE != Transport: type 3',
#  140: 'NAME_INCOME_TYPE != Working & REGION_RATING_CLIENT_W_CITY > 2.5 & ORGANIZATION_TYPE == Transport: type 3',
#  141: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_3 <= 0.265753 & EXT_SOURCE_3 <= -0.499736',
#  142: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_3 <= 0.265753 & EXT_SOURCE_3 > -0.499736',
#  143: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_3 > 0.265753 & EXT_SOURCE_3 <= 0.660215',
#  144: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_3 > 0.265753 & EXT_SOURCE_3 > 0.660215',
#  145: 'EXT_SOURCE_1 <= 0.423244 & DAYS_BIRTH <= -19935.5 & DAYS_ID_PUBLISH <= -507.5',
#  146: 'EXT_SOURCE_1 <= 0.423244 & DAYS_BIRTH <= -19935.5 & DAYS_ID_PUBLISH > -507.5',
#  147: 'EXT_SOURCE_1 <= 0.423244 & DAYS_BIRTH > -19935.5 & EXT_SOURCE_2 <= 0.391923',
#  148: 'EXT_SOURCE_1 <= 0.423244 & DAYS_BIRTH > -19935.5 & EXT_SOURCE_2 > 0.391923',
#  149: 'EXT_SOURCE_1 > 0.423244 & NAME_INCOME_TYPE != Maternity leave & DAYS_EMPLOYED <= -2887.5',
#  150: 'EXT_SOURCE_1 > 0.423244 & NAME_INCOME_TYPE != Maternity leave & DAYS_EMPLOYED > -2887.5',
#  151: 'EXT_SOURCE_1 > 0.423244 & NAME_INCOME_TYPE == Maternity leave',
#  152: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_3 <= 0.23337 & EXT_SOURCE_3 <= -0.499736',
#  153: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_3 <= 0.23337 & EXT_SOURCE_3 > -0.499736',
#  154: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_3 > 0.23337 & EXT_SOURCE_3 <= 0.652078',
#  155: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_3 > 0.23337 & EXT_SOURCE_3 > 0.652078',
#  156: 'NAME_EDUCATION_TYPE == Higher education & DAYS_EMPLOYED <= -4096.5 & FLAG_DOCUMENT_2 <= 0.5',
#  157: 'NAME_EDUCATION_TYPE == Higher education & DAYS_EMPLOYED <= -4096.5 & FLAG_DOCUMENT_2 > 0.5',
#  158: 'NAME_EDUCATION_TYPE == Higher education & DAYS_EMPLOYED > -4096.5 & EXT_SOURCE_2 <= 0.204558',
#  159: 'NAME_EDUCATION_TYPE == Higher education & DAYS_EMPLOYED > -4096.5 & EXT_SOURCE_2 > 0.204558',
#  160: 'EXT_SOURCE_2 <= 0.623427 & AMT_CREDIT <= 247830.75 & DAYS_REGISTRATION <= -7461.5',
#  161: 'EXT_SOURCE_2 <= 0.623427 & AMT_CREDIT <= 247830.75 & DAYS_REGISTRATION > -7461.5',
#  162: 'EXT_SOURCE_2 <= 0.623427 & AMT_CREDIT > 247830.75 & AMT_GOODS_PRICE <= 452250.0',
#  163: 'EXT_SOURCE_2 <= 0.623427 & AMT_CREDIT > 247830.75 & AMT_GOODS_PRICE > 452250.0',
#  164: 'EXT_SOURCE_2 > 0.623427 & EXT_SOURCE_2 <= 0.71894 & EXT_SOURCE_2 <= 0.718913',
#  165: 'EXT_SOURCE_2 > 0.623427 & EXT_SOURCE_2 <= 0.71894 & EXT_SOURCE_2 > 0.718913',
#  166: 'EXT_SOURCE_2 > 0.623427 & EXT_SOURCE_2 > 0.71894 & CNT_FAM_MEMBERS <= 5.5',
#  167: 'EXT_SOURCE_2 > 0.623427 & EXT_SOURCE_2 > 0.71894 & CNT_FAM_MEMBERS > 5.5',
#  168: 'FLAG_DOCUMENT_3 <= 0.5 & DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & AMT_ANNUITY <= 24804.0',
#  169: 'FLAG_DOCUMENT_3 <= 0.5 & DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & AMT_ANNUITY > 24804.0',
#  170: 'FLAG_DOCUMENT_3 <= 0.5 & DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & ORGANIZATION_TYPE != Transport: type 3',
#  171: 'FLAG_DOCUMENT_3 <= 0.5 & DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & ORGANIZATION_TYPE == Transport: type 3',
#  172: 'FLAG_DOCUMENT_3 > 0.5 & EXT_SOURCE_1 <= 0.423253 & EXT_SOURCE_3 <= 0.505583',
#  173: 'FLAG_DOCUMENT_3 > 0.5 & EXT_SOURCE_1 <= 0.423253 & EXT_SOURCE_3 > 0.505583',
#  174: 'FLAG_DOCUMENT_3 > 0.5 & EXT_SOURCE_1 > 0.423253 & DAYS_EMPLOYED <= -2741.5',
#  175: 'FLAG_DOCUMENT_3 > 0.5 & EXT_SOURCE_1 > 0.423253 & DAYS_EMPLOYED > -2741.5',
#  176: 'YEARS_BEGINEXPLUATATION_MODE <= 0.97395 & EXT_SOURCE_3 <= 0.516396 & FLAG_DOCUMENT_3 <= 0.5',
#  177: 'YEARS_BEGINEXPLUATATION_MODE <= 0.97395 & EXT_SOURCE_3 <= 0.516396 & FLAG_DOCUMENT_3 > 0.5',
#  178: 'YEARS_BEGINEXPLUATATION_MODE <= 0.97395 & EXT_SOURCE_3 > 0.516396 & DAYS_LAST_PHONE_CHANGE <= -3921.0',
#  179: 'YEARS_BEGINEXPLUATATION_MODE <= 0.97395 & EXT_SOURCE_3 > 0.516396 & DAYS_LAST_PHONE_CHANGE > -3921.0',
#  180: 'YEARS_BEGINEXPLUATATION_MODE > 0.97395 & EXT_SOURCE_2 <= 0.063515 & EXT_SOURCE_2 <= 0.061729',
#  181: 'YEARS_BEGINEXPLUATATION_MODE > 0.97395 & EXT_SOURCE_2 <= 0.063515 & EXT_SOURCE_2 > 0.061729',
#  182: 'YEARS_BEGINEXPLUATATION_MODE > 0.97395 & EXT_SOURCE_2 > 0.063515 & DEF_60_CNT_SOCIAL_CIRCLE <= 0.5',
#  183: 'YEARS_BEGINEXPLUATATION_MODE > 0.97395 & EXT_SOURCE_2 > 0.063515 & DEF_60_CNT_SOCIAL_CIRCLE > 0.5',
#  184: 'CODE_GENDER != F & FLAG_OWN_CAR != N & OCCUPATION_TYPE != Drivers',
#  185: 'CODE_GENDER != F & FLAG_OWN_CAR != N & OCCUPATION_TYPE == Drivers',
#  186: 'CODE_GENDER != F & FLAG_OWN_CAR == N & AMT_CREDIT <= 201246.75',
#  187: 'CODE_GENDER != F & FLAG_OWN_CAR == N & AMT_CREDIT > 201246.75',
#  188: 'CODE_GENDER == F & DAYS_BIRTH <= -14777.5 & LIVINGAPARTMENTS_MODE <= 0.00685',
#  189: 'CODE_GENDER == F & DAYS_BIRTH <= -14777.5 & LIVINGAPARTMENTS_MODE > 0.00685',
#  190: 'CODE_GENDER == F & DAYS_BIRTH > -14777.5 & EXT_SOURCE_1 <= 0.412304',
#  191: 'CODE_GENDER == F & DAYS_BIRTH > -14777.5 & EXT_SOURCE_1 > 0.412304',
#  192: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY <= 2.5 & CODE_GENDER != M',
#  193: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY <= 2.5 & CODE_GENDER == M',
#  194: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY > 2.5 & DAYS_REGISTRATION <= -3516.0',
#  195: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY > 2.5 & DAYS_REGISTRATION > -3516.0',
#  196: 'NAME_EDUCATION_TYPE == Higher education & AMT_ANNUITY <= 18517.5 & FONDKAPREMONT_MODE != not specified',
#  197: 'NAME_EDUCATION_TYPE == Higher education & AMT_ANNUITY <= 18517.5 & FONDKAPREMONT_MODE == not specified',
#  198: 'NAME_EDUCATION_TYPE == Higher education & AMT_ANNUITY > 18517.5 & AMT_GOODS_PRICE <= 139500.0',
#  199: 'NAME_EDUCATION_TYPE == Higher education & AMT_ANNUITY > 18517.5 & AMT_GOODS_PRICE > 139500.0',
#  200: 'AMT_CREDIT <= 274639.5 & DAYS_ID_PUBLISH <= -2851.5 & NAME_FAMILY_STATUS != Civil marriage',
#  201: 'AMT_CREDIT <= 274639.5 & DAYS_ID_PUBLISH <= -2851.5 & NAME_FAMILY_STATUS == Civil marriage',
#  202: 'AMT_CREDIT <= 274639.5 & DAYS_ID_PUBLISH > -2851.5 & DAYS_BIRTH <= -9039.5',
#  203: 'AMT_CREDIT <= 274639.5 & DAYS_ID_PUBLISH > -2851.5 & DAYS_BIRTH > -9039.5',
#  204: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE <= 452250.0 & AMT_CREDIT <= 473800.5',
#  205: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE <= 452250.0 & AMT_CREDIT > 473800.5',
#  206: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE > 452250.0 & AMT_REQ_CREDIT_BUREAU_WEEK <= 3.5',
#  207: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE > 452250.0 & AMT_REQ_CREDIT_BUREAU_WEEK > 3.5',
#  208: 'EXT_SOURCE_2 <= 0.653372 & AMT_ANNUITY <= 24167.25 & DAYS_ID_PUBLISH <= -494.5',
#  209: 'EXT_SOURCE_2 <= 0.653372 & AMT_ANNUITY <= 24167.25 & DAYS_ID_PUBLISH > -494.5',
#  210: 'EXT_SOURCE_2 <= 0.653372 & AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE <= 452250.0',
#  211: 'EXT_SOURCE_2 <= 0.653372 & AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE > 452250.0',
#  212: 'EXT_SOURCE_2 > 0.653372 & DEF_30_CNT_SOCIAL_CIRCLE <= 4.5 & DAYS_EMPLOYED <= -1269.5',
#  213: 'EXT_SOURCE_2 > 0.653372 & DEF_30_CNT_SOCIAL_CIRCLE <= 4.5 & DAYS_EMPLOYED > -1269.5',
#  214: 'EXT_SOURCE_2 > 0.653372 & DEF_30_CNT_SOCIAL_CIRCLE > 4.5',
#  215: 'NAME_INCOME_TYPE != Working & LIVINGAPARTMENTS_AVG <= 0.05055 & AMT_ANNUITY <= 26464.5',
#  216: 'NAME_INCOME_TYPE != Working & LIVINGAPARTMENTS_AVG <= 0.05055 & AMT_ANNUITY > 26464.5',
#  217: 'NAME_INCOME_TYPE != Working & LIVINGAPARTMENTS_AVG > 0.05055 & FLOORSMAX_MODE <= 0.9375',
#  218: 'NAME_INCOME_TYPE != Working & LIVINGAPARTMENTS_AVG > 0.05055 & FLOORSMAX_MODE > 0.9375',
#  219: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_1 <= 0.264604 & EXT_SOURCE_2 <= 0.255635',
#  220: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_1 <= 0.264604 & EXT_SOURCE_2 > 0.255635',
#  221: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_1 > 0.264604 & DEF_30_CNT_SOCIAL_CIRCLE <= 1.5',
#  222: 'NAME_INCOME_TYPE == Working & EXT_SOURCE_1 > 0.264604 & DEF_30_CNT_SOCIAL_CIRCLE > 1.5',
#  223: 'EXT_SOURCE_3 <= 0.647153 & NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_1 <= 0.265393',
#  224: 'EXT_SOURCE_3 <= 0.647153 & NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_1 > 0.265393',
#  225: 'EXT_SOURCE_3 <= 0.647153 & NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH <= -5.0',
#  226: 'EXT_SOURCE_3 <= 0.647153 & NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH > -5.0',
#  227: 'EXT_SOURCE_3 > 0.647153 & DAYS_LAST_PHONE_CHANGE <= -3960.5',
#  228: 'EXT_SOURCE_3 > 0.647153 & DAYS_LAST_PHONE_CHANGE > -3960.5 & ORGANIZATION_TYPE != Emergency',
#  229: 'EXT_SOURCE_3 > 0.647153 & DAYS_LAST_PHONE_CHANGE > -3960.5 & ORGANIZATION_TYPE == Emergency',
#  230: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_2 <= 0.07751 & FLAG_DOCUMENT_9 <= 0.5',
#  231: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_2 <= 0.07751 & FLAG_DOCUMENT_9 > 0.5',
#  232: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_2 > 0.07751 & DAYS_REGISTRATION <= -5706.5',
#  233: 'NAME_EDUCATION_TYPE != Higher education & EXT_SOURCE_2 > 0.07751 & DAYS_REGISTRATION > -5706.5',
#  234: 'NAME_EDUCATION_TYPE == Higher education & FLAG_DOCUMENT_2 <= 0.5 & DAYS_EMPLOYED <= -4096.5',
#  235: 'NAME_EDUCATION_TYPE == Higher education & FLAG_DOCUMENT_2 <= 0.5 & DAYS_EMPLOYED > -4096.5',
#  236: 'NAME_EDUCATION_TYPE == Higher education & FLAG_DOCUMENT_2 > 0.5',
#  237: 'AMT_CREDIT <= 274639.5 & ORGANIZATION_TYPE != Self-employed & DAYS_ID_PUBLISH <= -5.0',
#  238: 'AMT_CREDIT <= 274639.5 & ORGANIZATION_TYPE != Self-employed & DAYS_ID_PUBLISH > -5.0',
#  239: 'AMT_CREDIT <= 274639.5 & ORGANIZATION_TYPE == Self-employed & AMT_INCOME_TOTAL <= 393750.0',
#  240: 'AMT_CREDIT <= 274639.5 & ORGANIZATION_TYPE == Self-employed & AMT_INCOME_TOTAL > 393750.0',
#  241: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE <= 452250.0 & AMT_CREDIT <= 512241.75',
#  242: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE <= 452250.0 & AMT_CREDIT > 512241.75',
#  243: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE > 452250.0 & AMT_REQ_CREDIT_BUREAU_WEEK <= 3.5',
#  244: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE > 452250.0 & AMT_REQ_CREDIT_BUREAU_WEEK > 3.5',
#  245: 'EXT_SOURCE_1 <= 0.638821 & FLAG_DOCUMENT_3 <= 0.5 & EXT_SOURCE_2 <= 0.019638',
#  246: 'EXT_SOURCE_1 <= 0.638821 & FLAG_DOCUMENT_3 <= 0.5 & EXT_SOURCE_2 > 0.019638',
#  247: 'EXT_SOURCE_1 <= 0.638821 & FLAG_DOCUMENT_3 > 0.5 & EXT_SOURCE_3 <= 0.229521',
#  248: 'EXT_SOURCE_1 <= 0.638821 & FLAG_DOCUMENT_3 > 0.5 & EXT_SOURCE_3 > 0.229521',
#  249: 'EXT_SOURCE_1 > 0.638821 & ORGANIZATION_TYPE != Industry: type 2 & AMT_INCOME_TOTAL <= 1113750.0',
#  250: 'EXT_SOURCE_1 > 0.638821 & ORGANIZATION_TYPE != Industry: type 2 & AMT_INCOME_TOTAL > 1113750.0',
#  251: 'EXT_SOURCE_1 > 0.638821 & ORGANIZATION_TYPE == Industry: type 2 & WEEKDAY_APPR_PROCESS_START != TUESDAY',
#  252: 'EXT_SOURCE_1 > 0.638821 & ORGANIZATION_TYPE == Industry: type 2 & WEEKDAY_APPR_PROCESS_START == TUESDAY',
#  253: 'DAYS_EMPLOYED <= -3047.5 & CNT_FAM_MEMBERS <= 10.5 & LIVINGAPARTMENTS_MODE <= 0.08585',
#  254: 'DAYS_EMPLOYED <= -3047.5 & CNT_FAM_MEMBERS <= 10.5 & LIVINGAPARTMENTS_MODE > 0.08585',
#  255: 'DAYS_EMPLOYED <= -3047.5 & CNT_FAM_MEMBERS > 10.5',
#  256: 'DAYS_EMPLOYED > -3047.5 & REGION_RATING_CLIENT_W_CITY <= 2.5 & OCCUPATION_TYPE != null',
#  257: 'DAYS_EMPLOYED > -3047.5 & REGION_RATING_CLIENT_W_CITY <= 2.5 & OCCUPATION_TYPE == null',
#  258: 'DAYS_EMPLOYED > -3047.5 & REGION_RATING_CLIENT_W_CITY > 2.5 & EXT_SOURCE_2 <= 0.089251',
#  259: 'DAYS_EMPLOYED > -3047.5 & REGION_RATING_CLIENT_W_CITY > 2.5 & EXT_SOURCE_2 > 0.089251',
#  260: 'OCCUPATION_TYPE != Drivers & AMT_CREDIT <= 273330.0 & LIVINGAREA_AVG <= 0.1319',
#  261: 'OCCUPATION_TYPE != Drivers & AMT_CREDIT <= 273330.0 & LIVINGAREA_AVG > 0.1319',
#  262: 'OCCUPATION_TYPE != Drivers & AMT_CREDIT > 273330.0 & AMT_GOODS_PRICE <= 452250.0',
#  263: 'OCCUPATION_TYPE != Drivers & AMT_CREDIT > 273330.0 & AMT_GOODS_PRICE > 452250.0',
#  264: 'OCCUPATION_TYPE == Drivers & AMT_GOODS_PRICE <= 885827.25 & AMT_GOODS_PRICE <= 877500.0',
#  265: 'OCCUPATION_TYPE == Drivers & AMT_GOODS_PRICE <= 885827.25 & AMT_GOODS_PRICE > 877500.0',
#  266: 'OCCUPATION_TYPE == Drivers & AMT_GOODS_PRICE > 885827.25 & NAME_TYPE_SUITE != Other_B',
#  267: 'OCCUPATION_TYPE == Drivers & AMT_GOODS_PRICE > 885827.25 & NAME_TYPE_SUITE == Other_B',
#  268: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & YEARS_BEGINEXPLUATATION_MODE <= 0.97395 & AMT_ANNUITY <= 24720.75',
#  269: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & YEARS_BEGINEXPLUATATION_MODE <= 0.97395 & AMT_ANNUITY > 24720.75',
#  270: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & YEARS_BEGINEXPLUATATION_MODE > 0.97395 & EXT_SOURCE_2 <= 0.063515',
#  271: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & YEARS_BEGINEXPLUATATION_MODE > 0.97395 & EXT_SOURCE_2 > 0.063515',
#  272: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 <= 0.021649 & DAYS_REGISTRATION <= -7885.5',
#  273: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 <= 0.021649 & DAYS_REGISTRATION > -7885.5',
#  274: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 > 0.021649 & DAYS_ID_PUBLISH <= -1310.5',
#  275: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 > 0.021649 & DAYS_ID_PUBLISH > -1310.5',
#  276: 'EXT_SOURCE_2 <= 0.653372 & CODE_GENDER != M & DAYS_ID_PUBLISH <= -716.5',
#  277: 'EXT_SOURCE_2 <= 0.653372 & CODE_GENDER != M & DAYS_ID_PUBLISH > -716.5',
#  278: 'EXT_SOURCE_2 <= 0.653372 & CODE_GENDER == M & NAME_FAMILY_STATUS != Married',
#  279: 'EXT_SOURCE_2 <= 0.653372 & CODE_GENDER == M & NAME_FAMILY_STATUS == Married',
#  280: 'EXT_SOURCE_2 > 0.653372 & DEF_30_CNT_SOCIAL_CIRCLE <= 4.5 & AMT_GOODS_PRICE <= 677250.0',
#  281: 'EXT_SOURCE_2 > 0.653372 & DEF_30_CNT_SOCIAL_CIRCLE <= 4.5 & AMT_GOODS_PRICE > 677250.0',
#  282: 'EXT_SOURCE_2 > 0.653372 & DEF_30_CNT_SOCIAL_CIRCLE > 4.5',
#  283: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE != Working',
#  284: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE == Working',
#  285: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY > 2.5 & AMT_REQ_CREDIT_BUREAU_QRT <= 3.5',
#  286: 'NAME_EDUCATION_TYPE != Higher education & REGION_RATING_CLIENT_W_CITY > 2.5 & AMT_REQ_CREDIT_BUREAU_QRT > 3.5',
#  287: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 <= 0.000514 & HOUR_APPR_PROCESS_START <= 16.5',
#  288: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 <= 0.000514 & HOUR_APPR_PROCESS_START > 16.5',
#  289: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 > 0.000514 & EXT_SOURCE_2 <= 0.001012',
#  290: 'NAME_EDUCATION_TYPE == Higher education & EXT_SOURCE_2 > 0.000514 & EXT_SOURCE_2 > 0.001012',
#  291: 'EXT_SOURCE_3 <= 0.656971 & EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_MON <= -0.5',
#  292: 'EXT_SOURCE_3 <= 0.656971 & EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_MON > -0.5',
#  293: 'EXT_SOURCE_3 <= 0.656971 & EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 <= 0.145992',
#  294: 'EXT_SOURCE_3 <= 0.656971 & EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 > 0.145992',
#  295: 'EXT_SOURCE_3 > 0.656971 & ORGANIZATION_TYPE != Emergency & DEF_60_CNT_SOCIAL_CIRCLE <= 0.5',
#  296: 'EXT_SOURCE_3 > 0.656971 & ORGANIZATION_TYPE != Emergency & DEF_60_CNT_SOCIAL_CIRCLE > 0.5',
#  297: 'EXT_SOURCE_3 > 0.656971 & ORGANIZATION_TYPE == Emergency & NONLIVINGAREA_AVG <= 0.0004',
#  298: 'EXT_SOURCE_3 > 0.656971 & ORGANIZATION_TYPE == Emergency & NONLIVINGAREA_AVG > 0.0004',
#  299: 'DAYS_EMPLOYED <= -3047.5 & CNT_FAM_MEMBERS <= 10.5 & ORGANIZATION_TYPE != Construction',
#  300: 'DAYS_EMPLOYED <= -3047.5 & CNT_FAM_MEMBERS <= 10.5 & ORGANIZATION_TYPE == Construction',
#  301: 'DAYS_EMPLOYED <= -3047.5 & CNT_FAM_MEMBERS > 10.5',
#  302: 'DAYS_EMPLOYED > -3047.5 & AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START <= 0.5',
#  303: 'DAYS_EMPLOYED > -3047.5 & AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START > 0.5',
#  304: 'DAYS_EMPLOYED > -3047.5 & AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE <= 452250.0',
#  305: 'DAYS_EMPLOYED > -3047.5 & AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE > 452250.0',
#  306: 'EXT_SOURCE_1 <= 0.649877 & FLAG_DOCUMENT_3 <= 0.5 & AMT_REQ_CREDIT_BUREAU_WEEK <= 3.5',
#  307: 'EXT_SOURCE_1 <= 0.649877 & FLAG_DOCUMENT_3 <= 0.5 & AMT_REQ_CREDIT_BUREAU_WEEK > 3.5',
#  308: 'EXT_SOURCE_1 <= 0.649877 & FLAG_DOCUMENT_3 > 0.5 & AMT_GOODS_PRICE <= 677889.0',
#  309: 'EXT_SOURCE_1 <= 0.649877 & FLAG_DOCUMENT_3 > 0.5 & AMT_GOODS_PRICE > 677889.0',
#  310: 'EXT_SOURCE_1 > 0.649877 & EXT_SOURCE_2 <= 0.047366 & DAYS_ID_PUBLISH <= -5189.5',
#  311: 'EXT_SOURCE_1 > 0.649877 & EXT_SOURCE_2 <= 0.047366 & DAYS_ID_PUBLISH > -5189.5',
#  312: 'EXT_SOURCE_1 > 0.649877 & EXT_SOURCE_2 > 0.047366 & EXT_SOURCE_2 <= 0.048647',
#  313: 'EXT_SOURCE_1 > 0.649877 & EXT_SOURCE_2 > 0.047366 & EXT_SOURCE_2 > 0.048647',
#  314: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 <= 0.658595 & AMT_CREDIT <= 184907.25',
#  315: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 <= 0.658595 & AMT_CREDIT > 184907.25',
#  316: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 > 0.658595 & ORGANIZATION_TYPE != Emergency',
#  317: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 > 0.658595 & ORGANIZATION_TYPE == Emergency',
#  318: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH <= -4.5 & EXT_SOURCE_2 <= 0.152317',
#  319: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH <= -4.5 & EXT_SOURCE_2 > 0.152317',
#  320: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH > -4.5 & EXT_SOURCE_3 <= 0.329682',
#  321: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH > -4.5 & EXT_SOURCE_3 > 0.329682',
#  322: 'EXT_SOURCE_2 <= 0.718135 & CODE_GENDER != F & NAME_FAMILY_STATUS != Married',
#  323: 'EXT_SOURCE_2 <= 0.718135 & CODE_GENDER != F & NAME_FAMILY_STATUS == Married',
#  324: 'EXT_SOURCE_2 <= 0.718135 & CODE_GENDER == F & DAYS_BIRTH <= -14777.5',
#  325: 'EXT_SOURCE_2 <= 0.718135 & CODE_GENDER == F & DAYS_BIRTH > -14777.5',
#  326: 'EXT_SOURCE_2 > 0.718135 & FLAG_DOCUMENT_19 <= 0.5 & REGION_POPULATION_RELATIVE <= 0.001375',
#  327: 'EXT_SOURCE_2 > 0.718135 & FLAG_DOCUMENT_19 <= 0.5 & REGION_POPULATION_RELATIVE > 0.001375',
#  328: 'EXT_SOURCE_2 > 0.718135 & FLAG_DOCUMENT_19 > 0.5 & EXT_SOURCE_2 <= 0.750966',
#  329: 'EXT_SOURCE_2 > 0.718135 & FLAG_DOCUMENT_19 > 0.5 & EXT_SOURCE_2 > 0.750966',
#  330: 'AMT_CREDIT <= 274639.5 & AMT_CREDIT <= 102762.0 & EXT_SOURCE_3 <= 0.316252',
#  331: 'AMT_CREDIT <= 274639.5 & AMT_CREDIT <= 102762.0 & EXT_SOURCE_3 > 0.316252',
#  332: 'AMT_CREDIT <= 274639.5 & AMT_CREDIT > 102762.0 & DAYS_REGISTRATION <= -5503.5',
#  333: 'AMT_CREDIT <= 274639.5 & AMT_CREDIT > 102762.0 & DAYS_REGISTRATION > -5503.5',
#  334: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE <= 452250.0 & AMT_CREDIT <= 473800.5',
#  335: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE <= 452250.0 & AMT_CREDIT > 473800.5',
#  336: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE > 452250.0 & FLAG_DOCUMENT_21 <= 0.5',
#  337: 'AMT_CREDIT > 274639.5 & AMT_GOODS_PRICE > 452250.0 & FLAG_DOCUMENT_21 > 0.5',
#  338: 'NAME_EDUCATION_TYPE != Secondary / secondary special & YEARS_BEGINEXPLUATATION_MODE <= 0.98685 & COMMONAREA_MEDI <= 0.9948',
#  339: 'NAME_EDUCATION_TYPE != Secondary / secondary special & YEARS_BEGINEXPLUATATION_MODE <= 0.98685 & COMMONAREA_MEDI > 0.9948',
#  340: 'NAME_EDUCATION_TYPE != Secondary / secondary special & YEARS_BEGINEXPLUATATION_MODE > 0.98685 & ORGANIZATION_TYPE != Postal',
#  341: 'NAME_EDUCATION_TYPE != Secondary / secondary special & YEARS_BEGINEXPLUATATION_MODE > 0.98685 & ORGANIZATION_TYPE == Postal',
#  342: 'NAME_EDUCATION_TYPE == Secondary / secondary special & REG_CITY_NOT_LIVE_CITY <= 0.5 & DAYS_ID_PUBLISH <= -4723.5',
#  343: 'NAME_EDUCATION_TYPE == Secondary / secondary special & REG_CITY_NOT_LIVE_CITY <= 0.5 & DAYS_ID_PUBLISH > -4723.5',
#  344: 'NAME_EDUCATION_TYPE == Secondary / secondary special & REG_CITY_NOT_LIVE_CITY > 0.5 & EXT_SOURCE_3 <= 0.260162',
#  345: 'NAME_EDUCATION_TYPE == Secondary / secondary special & REG_CITY_NOT_LIVE_CITY > 0.5 & EXT_SOURCE_3 > 0.260162',
#  346: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_WEEK <= -0.5',
#  347: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_WEEK > -0.5',
#  348: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 <= 0.155217',
#  349: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 > 0.155217',
#  350: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 <= 0.012022 & EXT_SOURCE_2 <= 0.005596',
#  351: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 <= 0.012022 & EXT_SOURCE_2 > 0.005596',
#  352: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 > 0.012022 & DAYS_ID_PUBLISH <= -882.5',
#  353: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & EXT_SOURCE_2 > 0.012022 & DAYS_ID_PUBLISH > -882.5',
#  354: 'REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE != State servant & NAME_FAMILY_STATUS != Married',
#  355: 'REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE != State servant & NAME_FAMILY_STATUS == Married',
#  356: 'REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE == State servant & NONLIVINGAPARTMENTS_MODE <= 0.18285',
#  357: 'REGION_RATING_CLIENT_W_CITY <= 2.5 & NAME_INCOME_TYPE == State servant & NONLIVINGAPARTMENTS_MODE > 0.18285',
#  358: 'REGION_RATING_CLIENT_W_CITY > 2.5 & AMT_ANNUITY <= 13794.75 & AMT_REQ_CREDIT_BUREAU_QRT <= 3.5',
#  359: 'REGION_RATING_CLIENT_W_CITY > 2.5 & AMT_ANNUITY <= 13794.75 & AMT_REQ_CREDIT_BUREAU_QRT > 3.5',
#  360: 'REGION_RATING_CLIENT_W_CITY > 2.5 & AMT_ANNUITY > 13794.75 & AMT_ANNUITY <= 13893.75',
#  361: 'REGION_RATING_CLIENT_W_CITY > 2.5 & AMT_ANNUITY > 13794.75 & AMT_ANNUITY > 13893.75',
#  362: 'OCCUPATION_TYPE != Drivers & OWN_CAR_AGE <= -0.5 & CODE_GENDER != F',
#  363: 'OCCUPATION_TYPE != Drivers & OWN_CAR_AGE <= -0.5 & CODE_GENDER == F',
#  364: 'OCCUPATION_TYPE != Drivers & OWN_CAR_AGE > -0.5 & DAYS_LAST_PHONE_CHANGE <= -244.5',
#  365: 'OCCUPATION_TYPE != Drivers & OWN_CAR_AGE > -0.5 & DAYS_LAST_PHONE_CHANGE > -244.5',
#  366: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH <= -8444.0 & DAYS_REGISTRATION <= -5421.0',
#  367: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH <= -8444.0 & DAYS_REGISTRATION > -5421.0',
#  368: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH > -8444.0 & EXT_SOURCE_2 <= 0.407909',
#  369: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH > -8444.0 & EXT_SOURCE_2 > 0.407909',
#  370: 'YEARS_BEGINEXPLUATATION_MEDI <= 0.98185 & AMT_CREDIT <= 249909.75 & EXT_SOURCE_3 <= 0.87037',
#  371: 'YEARS_BEGINEXPLUATATION_MEDI <= 0.98185 & AMT_CREDIT <= 249909.75 & EXT_SOURCE_3 > 0.87037',
#  372: 'YEARS_BEGINEXPLUATATION_MEDI <= 0.98185 & AMT_CREDIT > 249909.75 & EXT_SOURCE_3 <= 0.264348',
#  373: 'YEARS_BEGINEXPLUATATION_MEDI <= 0.98185 & AMT_CREDIT > 249909.75 & EXT_SOURCE_3 > 0.264348',
#  374: 'YEARS_BEGINEXPLUATATION_MEDI > 0.98185 & DAYS_REGISTRATION <= -16402.5',
#  375: 'YEARS_BEGINEXPLUATATION_MEDI > 0.98185 & DAYS_REGISTRATION > -16402.5 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5',
#  376: 'YEARS_BEGINEXPLUATATION_MEDI > 0.98185 & DAYS_REGISTRATION > -16402.5 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5',
#  377: 'DAYS_EMPLOYED <= -1427.5 & DAYS_BIRTH <= -8535.5 & REGION_POPULATION_RELATIVE <= 0.001107',
#  378: 'DAYS_EMPLOYED <= -1427.5 & DAYS_BIRTH <= -8535.5 & REGION_POPULATION_RELATIVE > 0.001107',
#  379: 'DAYS_EMPLOYED <= -1427.5 & DAYS_BIRTH > -8535.5 & DAYS_LAST_PHONE_CHANGE <= -510.5',
#  380: 'DAYS_EMPLOYED <= -1427.5 & DAYS_BIRTH > -8535.5 & DAYS_LAST_PHONE_CHANGE > -510.5',
#  381: 'DAYS_EMPLOYED > -1427.5 & DAYS_BIRTH <= -23292.5 & DAYS_REGISTRATION <= -2.5',
#  382: 'DAYS_EMPLOYED > -1427.5 & DAYS_BIRTH <= -23292.5 & DAYS_REGISTRATION > -2.5',
#  383: 'DAYS_EMPLOYED > -1427.5 & DAYS_BIRTH > -23292.5 & DAYS_BIRTH <= -9788.5',
#  384: 'DAYS_EMPLOYED > -1427.5 & DAYS_BIRTH > -23292.5 & DAYS_BIRTH > -9788.5',
#  385: 'EXT_SOURCE_1 <= 0.649877 & AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START <= 0.5',
#  386: 'EXT_SOURCE_1 <= 0.649877 & AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START > 0.5',
#  387: 'EXT_SOURCE_1 <= 0.649877 & AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE <= 677250.0',
#  388: 'EXT_SOURCE_1 <= 0.649877 & AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE > 677250.0',
#  389: 'EXT_SOURCE_1 > 0.649877 & ORGANIZATION_TYPE != Industry: type 2 & AMT_INCOME_TOTAL <= 1113750.0',
#  390: 'EXT_SOURCE_1 > 0.649877 & ORGANIZATION_TYPE != Industry: type 2 & AMT_INCOME_TOTAL > 1113750.0',
#  391: 'EXT_SOURCE_1 > 0.649877 & ORGANIZATION_TYPE == Industry: type 2 & WEEKDAY_APPR_PROCESS_START != TUESDAY',
#  392: 'EXT_SOURCE_1 > 0.649877 & ORGANIZATION_TYPE == Industry: type 2 & WEEKDAY_APPR_PROCESS_START == TUESDAY',
#  393: 'DAYS_EMPLOYED <= -4649.5 & ORGANIZATION_TYPE != Realtor & FLAG_DOCUMENT_2 <= 0.5',
#  394: 'DAYS_EMPLOYED <= -4649.5 & ORGANIZATION_TYPE != Realtor & FLAG_DOCUMENT_2 > 0.5',
#  395: 'DAYS_EMPLOYED <= -4649.5 & ORGANIZATION_TYPE == Realtor',
#  396: 'DAYS_EMPLOYED > -4649.5 & REGION_RATING_CLIENT_W_CITY <= 2.5 & FLAG_DOCUMENT_18 <= 0.5',
#  397: 'DAYS_EMPLOYED > -4649.5 & REGION_RATING_CLIENT_W_CITY <= 2.5 & FLAG_DOCUMENT_18 > 0.5',
#  398: 'DAYS_EMPLOYED > -4649.5 & REGION_RATING_CLIENT_W_CITY > 2.5 & EXT_SOURCE_2 <= 0.065857',
#  399: 'DAYS_EMPLOYED > -4649.5 & REGION_RATING_CLIENT_W_CITY > 2.5 & EXT_SOURCE_2 > 0.065857',
#  400: 'EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_HOUR <= -0.5 & ORGANIZATION_TYPE != Cleaning',
#  401: 'EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_HOUR <= -0.5 & ORGANIZATION_TYPE == Cleaning',
#  402: 'EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_HOUR > -0.5 & REGION_POPULATION_RELATIVE <= 0.001375',
#  403: 'EXT_SOURCE_3 <= -0.499736 & AMT_REQ_CREDIT_BUREAU_HOUR > -0.5 & REGION_POPULATION_RELATIVE > 0.001375',
#  404: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 <= 0.145992 & DAYS_REGISTRATION <= -351.5',
#  405: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 <= 0.145992 & DAYS_REGISTRATION > -351.5',
#  406: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 > 0.145992 & FLAG_OWN_CAR != N',
#  407: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 > 0.145992 & FLAG_OWN_CAR == N',
#  408: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 <= 0.660215 & AMT_CREDIT <= 184907.25',
#  409: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 <= 0.660215 & AMT_CREDIT > 184907.25',
#  410: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 > 0.660215 & ORGANIZATION_TYPE != Emergency',
#  411: 'NONLIVINGAREA_AVG <= 0.00205 & EXT_SOURCE_3 > 0.660215 & ORGANIZATION_TYPE == Emergency',
#  412: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH <= -4.5 & YEARS_BEGINEXPLUATATION_MEDI <= 0.95555',
#  413: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH <= -4.5 & YEARS_BEGINEXPLUATATION_MEDI > 0.95555',
#  414: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH > -4.5 & EXT_SOURCE_3 <= 0.329682',
#  415: 'NONLIVINGAREA_AVG > 0.00205 & DAYS_ID_PUBLISH > -4.5 & EXT_SOURCE_3 > 0.329682',
#  416: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & FLAG_DOCUMENT_3 <= 0.5 & DAYS_REGISTRATION <= -242.5',
#  417: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & FLAG_DOCUMENT_3 <= 0.5 & DAYS_REGISTRATION > -242.5',
#  418: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & FLAG_DOCUMENT_3 > 0.5 & DAYS_EMPLOYED <= -1254.5',
#  419: 'DEF_60_CNT_SOCIAL_CIRCLE <= 0.5 & FLAG_DOCUMENT_3 > 0.5 & DAYS_EMPLOYED > -1254.5',
#  420: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & ORGANIZATION_TYPE != Transport: type 3 & ORGANIZATION_TYPE != Business Entity Type 1',
#  421: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & ORGANIZATION_TYPE != Transport: type 3 & ORGANIZATION_TYPE == Business Entity Type 1',
#  422: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & ORGANIZATION_TYPE == Transport: type 3 & DAYS_BIRTH <= -12097.0',
#  423: 'DEF_60_CNT_SOCIAL_CIRCLE > 0.5 & ORGANIZATION_TYPE == Transport: type 3 & DAYS_BIRTH > -12097.0',
#  424: 'ORGANIZATION_TYPE != Self-employed & EXT_SOURCE_3 <= 0.015787 & AMT_REQ_CREDIT_BUREAU_DAY <= -0.5',
#  425: 'ORGANIZATION_TYPE != Self-employed & EXT_SOURCE_3 <= 0.015787 & AMT_REQ_CREDIT_BUREAU_DAY > -0.5',
#  426: 'ORGANIZATION_TYPE != Self-employed & EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.073719',
#  427: 'ORGANIZATION_TYPE != Self-employed & EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 > 0.073719',
#  428: 'ORGANIZATION_TYPE == Self-employed & EXT_SOURCE_2 <= 0.374996 & BASEMENTAREA_MEDI <= 0.12215',
#  429: 'ORGANIZATION_TYPE == Self-employed & EXT_SOURCE_2 <= 0.374996 & BASEMENTAREA_MEDI > 0.12215',
#  430: 'ORGANIZATION_TYPE == Self-employed & EXT_SOURCE_2 > 0.374996 & OBS_30_CNT_SOCIAL_CIRCLE <= 5.5',
#  431: 'ORGANIZATION_TYPE == Self-employed & EXT_SOURCE_2 > 0.374996 & OBS_30_CNT_SOCIAL_CIRCLE > 5.5',
#  432: 'NAME_EDUCATION_TYPE != Secondary / secondary special & EXT_SOURCE_2 <= 0.000514 & OWN_CAR_AGE <= 42.5',
#  433: 'NAME_EDUCATION_TYPE != Secondary / secondary special & EXT_SOURCE_2 <= 0.000514 & OWN_CAR_AGE > 42.5',
#  434: 'NAME_EDUCATION_TYPE != Secondary / secondary special & EXT_SOURCE_2 > 0.000514 & EXT_SOURCE_2 <= 0.001012',
#  435: 'NAME_EDUCATION_TYPE != Secondary / secondary special & EXT_SOURCE_2 > 0.000514 & EXT_SOURCE_2 > 0.001012',
#  436: 'NAME_EDUCATION_TYPE == Secondary / secondary special & CODE_GENDER != F & REGION_POPULATION_RELATIVE <= 0.003815',
#  437: 'NAME_EDUCATION_TYPE == Secondary / secondary special & CODE_GENDER != F & REGION_POPULATION_RELATIVE > 0.003815',
#  438: 'NAME_EDUCATION_TYPE == Secondary / secondary special & CODE_GENDER == F & DAYS_BIRTH <= -14777.5',
#  439: 'NAME_EDUCATION_TYPE == Secondary / secondary special & CODE_GENDER == F & DAYS_BIRTH > -14777.5',
#  440: 'EXT_SOURCE_2 <= 0.718135 & NAME_FAMILY_STATUS != Married & CODE_GENDER != M',
#  441: 'EXT_SOURCE_2 <= 0.718135 & NAME_FAMILY_STATUS != Married & CODE_GENDER == M',
#  442: 'EXT_SOURCE_2 <= 0.718135 & NAME_FAMILY_STATUS == Married & OCCUPATION_TYPE != null',
#  443: 'EXT_SOURCE_2 <= 0.718135 & NAME_FAMILY_STATUS == Married & OCCUPATION_TYPE == null',
#  444: 'EXT_SOURCE_2 > 0.718135 & NAME_TYPE_SUITE != Family & CNT_CHILDREN <= 3.5',
#  445: 'EXT_SOURCE_2 > 0.718135 & NAME_TYPE_SUITE != Family & CNT_CHILDREN > 3.5',
#  446: 'EXT_SOURCE_2 > 0.718135 & NAME_TYPE_SUITE == Family & NAME_HOUSING_TYPE != Co-op apartment',
#  447: 'EXT_SOURCE_2 > 0.718135 & NAME_TYPE_SUITE == Family & NAME_HOUSING_TYPE == Co-op apartment',
#  448: 'FLAG_OWN_CAR != N & OWN_CAR_AGE <= 7.5 & DAYS_BIRTH <= -7717.5',
#  449: 'FLAG_OWN_CAR != N & OWN_CAR_AGE <= 7.5 & DAYS_BIRTH > -7717.5',
#  450: 'FLAG_OWN_CAR != N & OWN_CAR_AGE > 7.5 & DAYS_REGISTRATION <= -1170.5',
#  451: 'FLAG_OWN_CAR != N & OWN_CAR_AGE > 7.5 & DAYS_REGISTRATION > -1170.5',
#  452: 'FLAG_OWN_CAR == N & CODE_GENDER != F & DAYS_BIRTH <= -10814.0',
#  453: 'FLAG_OWN_CAR == N & CODE_GENDER != F & DAYS_BIRTH > -10814.0',
#  454: 'FLAG_OWN_CAR == N & CODE_GENDER == F & DAYS_REGISTRATION <= -379.5',
#  455: 'FLAG_OWN_CAR == N & CODE_GENDER == F & DAYS_REGISTRATION > -379.5',
#  456: 'DAYS_ID_PUBLISH <= -4200.5 & EXT_SOURCE_3 <= 0.013169 & NAME_TYPE_SUITE != Group of people',
#  457: 'DAYS_ID_PUBLISH <= -4200.5 & EXT_SOURCE_3 <= 0.013169 & NAME_TYPE_SUITE == Group of people',
#  458: 'DAYS_ID_PUBLISH <= -4200.5 & EXT_SOURCE_3 > 0.013169 & EXT_SOURCE_3 <= 0.059228',
#  459: 'DAYS_ID_PUBLISH <= -4200.5 & EXT_SOURCE_3 > 0.013169 & EXT_SOURCE_3 > 0.059228',
#  460: 'DAYS_ID_PUBLISH > -4200.5 & DAYS_BIRTH <= -10139.5 & EXT_SOURCE_2 <= 0.382082',
#  461: 'DAYS_ID_PUBLISH > -4200.5 & DAYS_BIRTH <= -10139.5 & EXT_SOURCE_2 > 0.382082',
#  462: 'DAYS_ID_PUBLISH > -4200.5 & DAYS_BIRTH > -10139.5 & DAYS_ID_PUBLISH <= -719.5',
#  463: 'DAYS_ID_PUBLISH > -4200.5 & DAYS_BIRTH > -10139.5 & DAYS_ID_PUBLISH > -719.5',
#  464: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE != Industry: type 4 & LANDAREA_MEDI <= 0.321',
#  465: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE != Industry: type 4 & LANDAREA_MEDI > 0.321',
#  466: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE == Industry: type 4 & HOUR_APPR_PROCESS_START <= 11.5',
#  467: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE == Industry: type 4 & HOUR_APPR_PROCESS_START > 11.5',
#  468: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED <= -1427.5 & AMT_CREDIT <= 117081.0',
#  469: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED <= -1427.5 & AMT_CREDIT > 117081.0',
#  470: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED > -1427.5 & EXT_SOURCE_2 <= 0.062746',
#  471: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED > -1427.5 & EXT_SOURCE_2 > 0.062746',
#  472: 'YEARS_BUILD_AVG <= 0.7178 & NAME_FAMILY_STATUS != Married & ORGANIZATION_TYPE != Legal Services',
#  473: 'YEARS_BUILD_AVG <= 0.7178 & NAME_FAMILY_STATUS != Married & ORGANIZATION_TYPE == Legal Services',
#  474: 'YEARS_BUILD_AVG <= 0.7178 & NAME_FAMILY_STATUS == Married & FLAG_DOCUMENT_21 <= 0.5',
#  475: 'YEARS_BUILD_AVG <= 0.7178 & NAME_FAMILY_STATUS == Married & FLAG_DOCUMENT_21 > 0.5',
#  476: 'YEARS_BUILD_AVG > 0.7178 & HOUR_APPR_PROCESS_START <= 12.5 & EXT_SOURCE_2 <= 0.002084',
#  477: 'YEARS_BUILD_AVG > 0.7178 & HOUR_APPR_PROCESS_START <= 12.5 & EXT_SOURCE_2 > 0.002084',
#  478: 'YEARS_BUILD_AVG > 0.7178 & HOUR_APPR_PROCESS_START > 12.5 & LANDAREA_MEDI <= 0.89385',
#  479: 'YEARS_BUILD_AVG > 0.7178 & HOUR_APPR_PROCESS_START > 12.5 & LANDAREA_MEDI > 0.89385',
#  480: 'AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START <= 0.5 & FLOORSMAX_MEDI <= -0.27085',
#  481: 'AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START <= 0.5 & FLOORSMAX_MEDI > -0.27085',
#  482: 'AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START > 0.5 & AMT_ANNUITY <= 23481.0',
#  483: 'AMT_ANNUITY <= 24167.25 & HOUR_APPR_PROCESS_START > 0.5 & AMT_ANNUITY > 23481.0',
#  484: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE <= 677250.0 & AMT_CREDIT <= 358859.25',
#  485: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE <= 677250.0 & AMT_CREDIT > 358859.25',
#  486: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE > 677250.0 & DAYS_BIRTH <= -23986.0',
#  487: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE > 677250.0 & DAYS_BIRTH > -23986.0',
#  488: 'EXT_SOURCE_3 <= -0.499736 & WEEKDAY_APPR_PROCESS_START != TUESDAY & DEF_30_CNT_SOCIAL_CIRCLE <= 4.5',
#  489: 'EXT_SOURCE_3 <= -0.499736 & WEEKDAY_APPR_PROCESS_START != TUESDAY & DEF_30_CNT_SOCIAL_CIRCLE > 4.5',
#  490: 'EXT_SOURCE_3 <= -0.499736 & WEEKDAY_APPR_PROCESS_START == TUESDAY & EXT_SOURCE_2 <= 0.035204',
#  491: 'EXT_SOURCE_3 <= -0.499736 & WEEKDAY_APPR_PROCESS_START == TUESDAY & EXT_SOURCE_2 > 0.035204',
#  492: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 <= 0.145992 & ORGANIZATION_TYPE != Trade: type 7',
#  493: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 <= 0.145992 & ORGANIZATION_TYPE == Trade: type 7',
#  494: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 > 0.145992 & OCCUPATION_TYPE != Core staff',
#  495: 'EXT_SOURCE_3 > -0.499736 & EXT_SOURCE_3 > 0.145992 & OCCUPATION_TYPE == Core staff',
#  496: 'EXT_SOURCE_1 <= 0.638821 & AMT_ANNUITY <= 24720.75 & DAYS_ID_PUBLISH <= -494.5',
#  497: 'EXT_SOURCE_1 <= 0.638821 & AMT_ANNUITY <= 24720.75 & DAYS_ID_PUBLISH > -494.5',
#  498: 'EXT_SOURCE_1 <= 0.638821 & AMT_ANNUITY > 24720.75 & AMT_GOODS_PRICE <= 452250.0',
#  499: 'EXT_SOURCE_1 <= 0.638821 & AMT_ANNUITY > 24720.75 & AMT_GOODS_PRICE > 452250.0',
#  500: 'EXT_SOURCE_1 > 0.638821 & DAYS_ID_PUBLISH <= -13.5 & ORGANIZATION_TYPE != Industry: type 2',
#  501: 'EXT_SOURCE_1 > 0.638821 & DAYS_ID_PUBLISH <= -13.5 & ORGANIZATION_TYPE == Industry: type 2',
#  502: 'EXT_SOURCE_1 > 0.638821 & DAYS_ID_PUBLISH > -13.5 & EXT_SOURCE_1 <= 0.665637',
#  503: 'EXT_SOURCE_1 > 0.638821 & DAYS_ID_PUBLISH > -13.5 & EXT_SOURCE_1 > 0.665637',
#  504: 'OCCUPATION_TYPE != Drivers & FLAG_OWN_CAR != N & DAYS_LAST_PHONE_CHANGE <= -244.5',
#  505: 'OCCUPATION_TYPE != Drivers & FLAG_OWN_CAR != N & DAYS_LAST_PHONE_CHANGE > -244.5',
#  506: 'OCCUPATION_TYPE != Drivers & FLAG_OWN_CAR == N & OCCUPATION_TYPE != Laborers',
#  507: 'OCCUPATION_TYPE != Drivers & FLAG_OWN_CAR == N & OCCUPATION_TYPE == Laborers',
#  508: 'OCCUPATION_TYPE == Drivers & ORGANIZATION_TYPE != Self-employed & REGION_POPULATION_RELATIVE <= 0.003815',
#  509: 'OCCUPATION_TYPE == Drivers & ORGANIZATION_TYPE != Self-employed & REGION_POPULATION_RELATIVE > 0.003815',
#  510: 'OCCUPATION_TYPE == Drivers & ORGANIZATION_TYPE == Self-employed & EXT_SOURCE_2 <= 0.086242',
#  511: 'OCCUPATION_TYPE == Drivers & ORGANIZATION_TYPE == Self-employed & EXT_SOURCE_2 > 0.086242',
#  512: 'NONLIVINGAREA_AVG <= 0.00205 & NONLIVINGAREA_MEDI <= 0.0024 & NAME_INCOME_TYPE != Working',
#  513: 'NONLIVINGAREA_AVG <= 0.00205 & NONLIVINGAREA_MEDI <= 0.0024 & NAME_INCOME_TYPE == Working',
#  514: 'NONLIVINGAREA_AVG <= 0.00205 & NONLIVINGAREA_MEDI > 0.0024',
#  515: 'NONLIVINGAREA_AVG > 0.00205 & OBS_60_CNT_SOCIAL_CIRCLE <= 16.5 & AMT_INCOME_TOTAL <= 162225.0',
#  516: 'NONLIVINGAREA_AVG > 0.00205 & OBS_60_CNT_SOCIAL_CIRCLE <= 16.5 & AMT_INCOME_TOTAL > 162225.0',
# ...
#  608: 'DAYS_ID_PUBLISH <= -4723.5 & EXT_SOURCE_3 <= 0.013169 & DAYS_REGISTRATION <= -1.5',
#  609: 'DAYS_ID_PUBLISH <= -4723.5 & EXT_SOURCE_3 <= 0.013169 & DAYS_REGISTRATION > -1.5',
#  610: 'DAYS_ID_PUBLISH <= -4723.5 & EXT_SOURCE_3 > 0.013169 & EXT_SOURCE_3 <= 0.054962',
#  611: 'DAYS_ID_PUBLISH <= -4723.5 & EXT_SOURCE_3 > 0.013169 & EXT_SOURCE_3 > 0.054962',
#  612: 'DAYS_ID_PUBLISH > -4723.5 & DAYS_ID_PUBLISH <= -4713.5 & BASEMENTAREA_MODE <= 0.188',
#  613: 'DAYS_ID_PUBLISH > -4723.5 & DAYS_ID_PUBLISH <= -4713.5 & BASEMENTAREA_MODE > 0.188',
#  614: 'DAYS_ID_PUBLISH > -4723.5 & DAYS_ID_PUBLISH > -4713.5 & FLAG_DOCUMENT_3 <= 0.5',
#  615: 'DAYS_ID_PUBLISH > -4723.5 & DAYS_ID_PUBLISH > -4713.5 & FLAG_DOCUMENT_3 > 0.5',
#  616: 'ORGANIZATION_TYPE != Industry: type 9 & NAME_EDUCATION_TYPE != Higher education & REGION_POPULATION_RELATIVE <= 0.003815',
#  617: 'ORGANIZATION_TYPE != Industry: type 9 & NAME_EDUCATION_TYPE != Higher education & REGION_POPULATION_RELATIVE > 0.003815',
#  618: 'ORGANIZATION_TYPE != Industry: type 9 & NAME_EDUCATION_TYPE == Higher education & NONLIVINGAREA_MODE <= 0.9539',
#  619: 'ORGANIZATION_TYPE != Industry: type 9 & NAME_EDUCATION_TYPE == Higher education & NONLIVINGAREA_MODE > 0.9539',
#  620: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 <= 0.235268 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5',
#  621: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 <= 0.235268 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5',
#  622: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 > 0.235268 & FLAG_DOCUMENT_19 <= 0.5',
#  623: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 > 0.235268 & FLAG_DOCUMENT_19 > 0.5',
#  624: 'DAYS_EMPLOYED <= -11687.5 & NONLIVINGAREA_MODE <= 0.1343 & ORGANIZATION_TYPE != University',
#  625: 'DAYS_EMPLOYED <= -11687.5 & NONLIVINGAREA_MODE <= 0.1343 & ORGANIZATION_TYPE == University',
#  626: 'DAYS_EMPLOYED <= -11687.5 & NONLIVINGAREA_MODE > 0.1343 & APARTMENTS_AVG <= 0.04635',
#  627: 'DAYS_EMPLOYED <= -11687.5 & NONLIVINGAREA_MODE > 0.1343 & APARTMENTS_AVG > 0.04635',
#  628: 'DAYS_EMPLOYED > -11687.5 & DAYS_EMPLOYED <= -11685.5',
#  629: 'DAYS_EMPLOYED > -11687.5 & DAYS_EMPLOYED > -11685.5 & FLAG_OWN_CAR != Y',
#  630: 'DAYS_EMPLOYED > -11687.5 & DAYS_EMPLOYED > -11685.5 & FLAG_OWN_CAR == Y',
#  631: 'AMT_ANNUITY <= 24167.25 & AMT_ANNUITY <= 23469.75 & HOUR_APPR_PROCESS_START <= 0.5',
#  632: 'AMT_ANNUITY <= 24167.25 & AMT_ANNUITY <= 23469.75 & HOUR_APPR_PROCESS_START > 0.5',
#  633: 'AMT_ANNUITY <= 24167.25 & AMT_ANNUITY > 23469.75 & WALLSMATERIAL_MODE != Mixed',
#  634: 'AMT_ANNUITY <= 24167.25 & AMT_ANNUITY > 23469.75 & WALLSMATERIAL_MODE == Mixed',
#  635: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE <= 677250.0 & AMT_CREDIT <= 515643.75',
#  636: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE <= 677250.0 & AMT_CREDIT > 515643.75',
#  637: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE > 677250.0 & AMT_CREDIT <= 849550.5',
#  638: 'AMT_ANNUITY > 24167.25 & AMT_GOODS_PRICE > 677250.0 & AMT_CREDIT > 849550.5',
#  639: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START != TUESDAY & DEF_30_CNT_SOCIAL_CIRCLE <= 4.5',
#  640: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START != TUESDAY & DEF_30_CNT_SOCIAL_CIRCLE > 4.5',
#  641: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START == TUESDAY & EXT_SOURCE_2 <= 0.035204',
#  642: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START == TUESDAY & EXT_SOURCE_2 > 0.035204',
#  643: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & LIVINGAREA_AVG <= 0.09105',
#  644: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & LIVINGAREA_AVG > 0.09105',
#  645: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 > 0.058627 & EXT_SOURCE_3 <= 0.155217',
#  646: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 > 0.058627 & EXT_SOURCE_3 > 0.155217',
#  647: 'YEARS_BUILD_MEDI <= 0.74845 & OCCUPATION_TYPE != Laborers & ORGANIZATION_TYPE != Self-employed',
#  648: 'YEARS_BUILD_MEDI <= 0.74845 & OCCUPATION_TYPE != Laborers & ORGANIZATION_TYPE == Self-employed',
#  649: 'YEARS_BUILD_MEDI <= 0.74845 & OCCUPATION_TYPE == Laborers & DAYS_EMPLOYED <= -1030.5',
#  650: 'YEARS_BUILD_MEDI <= 0.74845 & OCCUPATION_TYPE == Laborers & DAYS_EMPLOYED > -1030.5',
#  651: 'YEARS_BUILD_MEDI > 0.74845 & DAYS_REGISTRATION <= -16165.5',
#  652: 'YEARS_BUILD_MEDI > 0.74845 & DAYS_REGISTRATION > -16165.5 & HOUR_APPR_PROCESS_START <= 12.5',
#  653: 'YEARS_BUILD_MEDI > 0.74845 & DAYS_REGISTRATION > -16165.5 & HOUR_APPR_PROCESS_START > 12.5',
#  654: 'OCCUPATION_TYPE != Drivers & ORGANIZATION_TYPE != Construction & FLAG_OWN_CAR != N',
#  655: 'OCCUPATION_TYPE != Drivers & ORGANIZATION_TYPE != Construction & FLAG_OWN_CAR == N',
#  656: 'OCCUPATION_TYPE != Drivers & ORGANIZATION_TYPE == Construction & EXT_SOURCE_2 <= 0.565228',
#  657: 'OCCUPATION_TYPE != Drivers & ORGANIZATION_TYPE == Construction & EXT_SOURCE_2 > 0.565228',
#  658: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH <= -8428.5 & NAME_FAMILY_STATUS != Widow',
#  659: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH <= -8428.5 & NAME_FAMILY_STATUS == Widow',
#  660: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH > -8428.5 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5',
#  661: 'OCCUPATION_TYPE == Drivers & DAYS_BIRTH > -8428.5 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5',
#  662: 'AMT_REQ_CREDIT_BUREAU_QRT <= 0.5 & AMT_CREDIT <= 252011.25 & NAME_INCOME_TYPE != Commercial associate',
#  663: 'AMT_REQ_CREDIT_BUREAU_QRT <= 0.5 & AMT_CREDIT <= 252011.25 & NAME_INCOME_TYPE == Commercial associate',
#  664: 'AMT_REQ_CREDIT_BUREAU_QRT <= 0.5 & AMT_CREDIT > 252011.25 & AMT_CREDIT <= 252141.75',
#  665: 'AMT_REQ_CREDIT_BUREAU_QRT <= 0.5 & AMT_CREDIT > 252011.25 & AMT_CREDIT > 252141.75',
#  666: 'AMT_REQ_CREDIT_BUREAU_QRT > 0.5 & EXT_SOURCE_2 <= 0.039043 & DAYS_LAST_PHONE_CHANGE <= -728.5',
#  667: 'AMT_REQ_CREDIT_BUREAU_QRT > 0.5 & EXT_SOURCE_2 <= 0.039043 & DAYS_LAST_PHONE_CHANGE > -728.5',
#  668: 'AMT_REQ_CREDIT_BUREAU_QRT > 0.5 & EXT_SOURCE_2 > 0.039043 & OBS_60_CNT_SOCIAL_CIRCLE <= 13.5',
#  669: 'AMT_REQ_CREDIT_BUREAU_QRT > 0.5 & EXT_SOURCE_2 > 0.039043 & OBS_60_CNT_SOCIAL_CIRCLE > 13.5',
#  670: 'AMT_ANNUITY <= 63510.75 & AMT_ANNUITY <= 63495.0 & DAYS_ID_PUBLISH <= -4171.5',
#  671: 'AMT_ANNUITY <= 63510.75 & AMT_ANNUITY <= 63495.0 & DAYS_ID_PUBLISH > -4171.5',
#  672: 'AMT_ANNUITY <= 63510.75 & AMT_ANNUITY > 63495.0',
#  673: 'AMT_ANNUITY > 63510.75 & AMT_INCOME_TOTAL <= 58500.0',
#  674: 'AMT_ANNUITY > 63510.75 & AMT_INCOME_TOTAL > 58500.0 & DAYS_REGISTRATION <= -15.0',
#  675: 'AMT_ANNUITY > 63510.75 & AMT_INCOME_TOTAL > 58500.0 & DAYS_REGISTRATION > -15.0',
#  676: 'DAYS_LAST_PHONE_CHANGE <= -2331.5 & REG_REGION_NOT_LIVE_REGION <= 0.5 & APARTMENTS_MEDI <= 0.0817',
#  677: 'DAYS_LAST_PHONE_CHANGE <= -2331.5 & REG_REGION_NOT_LIVE_REGION <= 0.5 & APARTMENTS_MEDI > 0.0817',
#  678: 'DAYS_LAST_PHONE_CHANGE <= -2331.5 & REG_REGION_NOT_LIVE_REGION > 0.5 & DAYS_ID_PUBLISH <= -3211.5',
#  679: 'DAYS_LAST_PHONE_CHANGE <= -2331.5 & REG_REGION_NOT_LIVE_REGION > 0.5 & DAYS_ID_PUBLISH > -3211.5',
#  680: 'DAYS_LAST_PHONE_CHANGE > -2331.5 & OCCUPATION_TYPE != Core staff & DAYS_ID_PUBLISH <= -247.5',
#  681: 'DAYS_LAST_PHONE_CHANGE > -2331.5 & OCCUPATION_TYPE != Core staff & DAYS_ID_PUBLISH > -247.5',
#  682: 'DAYS_LAST_PHONE_CHANGE > -2331.5 & OCCUPATION_TYPE == Core staff & HOUSETYPE_MODE != terraced house',
#  683: 'DAYS_LAST_PHONE_CHANGE > -2331.5 & OCCUPATION_TYPE == Core staff & HOUSETYPE_MODE == terraced house',
#  684: 'NAME_INCOME_TYPE != Maternity leave & DAYS_BIRTH <= -10139.5 & DAYS_BIRTH <= -10141.5',
#  685: 'NAME_INCOME_TYPE != Maternity leave & DAYS_BIRTH <= -10139.5 & DAYS_BIRTH > -10141.5',
#  686: 'NAME_INCOME_TYPE != Maternity leave & DAYS_BIRTH > -10139.5 & DAYS_ID_PUBLISH <= -719.5',
#  687: 'NAME_INCOME_TYPE != Maternity leave & DAYS_BIRTH > -10139.5 & DAYS_ID_PUBLISH > -719.5',
#  688: 'NAME_INCOME_TYPE == Maternity leave',
#  689: 'EXT_SOURCE_1 <= 0.638821 & EXT_SOURCE_1 <= 0.638816 & FLAG_WORK_PHONE <= 0.5',
#  690: 'EXT_SOURCE_1 <= 0.638821 & EXT_SOURCE_1 <= 0.638816 & FLAG_WORK_PHONE > 0.5',
#  691: 'EXT_SOURCE_1 <= 0.638821 & EXT_SOURCE_1 > 0.638816',
#  692: 'EXT_SOURCE_1 > 0.638821 & AMT_INCOME_TOTAL <= 1113750.0 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5',
#  693: 'EXT_SOURCE_1 > 0.638821 & AMT_INCOME_TOTAL <= 1113750.0 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5',
#  694: 'EXT_SOURCE_1 > 0.638821 & AMT_INCOME_TOTAL > 1113750.0 & FLOORSMAX_AVG <= 0.35415',
#  695: 'EXT_SOURCE_1 > 0.638821 & AMT_INCOME_TOTAL > 1113750.0 & FLOORSMAX_AVG > 0.35415',
#  696: 'FLAG_DOCUMENT_18 <= 0.5 & NAME_CONTRACT_TYPE != Revolving loans & OWN_CAR_AGE <= 40.5',
#  697: 'FLAG_DOCUMENT_18 <= 0.5 & NAME_CONTRACT_TYPE != Revolving loans & OWN_CAR_AGE > 40.5',
#  698: 'FLAG_DOCUMENT_18 <= 0.5 & NAME_CONTRACT_TYPE == Revolving loans & OWN_CAR_AGE <= 53.0',
#  699: 'FLAG_DOCUMENT_18 <= 0.5 & NAME_CONTRACT_TYPE == Revolving loans & OWN_CAR_AGE > 53.0',
#  700: 'FLAG_DOCUMENT_18 > 0.5 & NAME_HOUSING_TYPE != Office apartment & OCCUPATION_TYPE != Secretaries',
#  701: 'FLAG_DOCUMENT_18 > 0.5 & NAME_HOUSING_TYPE != Office apartment & OCCUPATION_TYPE == Secretaries',
#  702: 'FLAG_DOCUMENT_18 > 0.5 & NAME_HOUSING_TYPE == Office apartment',
#  703: 'EXT_SOURCE_2 <= -0.499997 & EXT_SOURCE_3 <= 0.230169 & WEEKDAY_APPR_PROCESS_START != SATURDAY',
#  704: 'EXT_SOURCE_2 <= -0.499997 & EXT_SOURCE_3 <= 0.230169 & WEEKDAY_APPR_PROCESS_START == SATURDAY',
#  705: 'EXT_SOURCE_2 <= -0.499997 & EXT_SOURCE_3 > 0.230169 & AMT_INCOME_TOTAL <= 85500.0',
#  706: 'EXT_SOURCE_2 <= -0.499997 & EXT_SOURCE_3 > 0.230169 & AMT_INCOME_TOTAL > 85500.0',
#  707: 'EXT_SOURCE_2 > -0.499997 & EXT_SOURCE_2 <= 9.9e-05 & NAME_INCOME_TYPE != Commercial associate',
#  708: 'EXT_SOURCE_2 > -0.499997 & EXT_SOURCE_2 <= 9.9e-05 & NAME_INCOME_TYPE == Commercial associate',
#  709: 'EXT_SOURCE_2 > -0.499997 & EXT_SOURCE_2 > 9.9e-05 & NAME_FAMILY_STATUS != Married',
#  710: 'EXT_SOURCE_2 > -0.499997 & EXT_SOURCE_2 > 9.9e-05 & NAME_FAMILY_STATUS == Married',
#  711: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE != Transport: type 4 & ORGANIZATION_TYPE != Industry: type 4',
#  712: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE != Transport: type 4 & ORGANIZATION_TYPE == Industry: type 4',
#  713: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE == Transport: type 4 & DAYS_REGISTRATION <= -8909.5',
#  714: 'AMT_CREDIT <= 113753.25 & ORGANIZATION_TYPE == Transport: type 4 & DAYS_REGISTRATION > -8909.5',
#  715: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED <= -1427.5 & AMT_CREDIT <= 117081.0',
#  716: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED <= -1427.5 & AMT_CREDIT > 117081.0',
#  717: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED > -1427.5 & DAYS_BIRTH <= -9788.5',
#  718: 'AMT_CREDIT > 113753.25 & DAYS_EMPLOYED > -1427.5 & DAYS_BIRTH > -9788.5',
#  719: 'DAYS_BIRTH <= -23761.5 & DAYS_REGISTRATION <= -3.0 & ORGANIZATION_TYPE != Industry: type 11',
#  720: 'DAYS_BIRTH <= -23761.5 & DAYS_REGISTRATION <= -3.0 & ORGANIZATION_TYPE == Industry: type 11',
#  721: 'DAYS_BIRTH <= -23761.5 & DAYS_REGISTRATION > -3.0',
#  722: 'DAYS_BIRTH > -23761.5 & EXT_SOURCE_1 <= 0.265403 & EXT_SOURCE_1 <= 0.018347',
#  723: 'DAYS_BIRTH > -23761.5 & EXT_SOURCE_1 <= 0.265403 & EXT_SOURCE_1 > 0.018347',
#  724: 'DAYS_BIRTH > -23761.5 & EXT_SOURCE_1 > 0.265403 & DAYS_BIRTH <= -15358.0',
#  725: 'DAYS_BIRTH > -23761.5 & EXT_SOURCE_1 > 0.265403 & DAYS_BIRTH > -15358.0',
#  726: 'EXT_SOURCE_3 <= 0.015787 & DAYS_ID_PUBLISH <= -4796.5 & LIVINGAPARTMENTS_AVG <= 0.36605',
#  727: 'EXT_SOURCE_3 <= 0.015787 & DAYS_ID_PUBLISH <= -4796.5 & LIVINGAPARTMENTS_AVG > 0.36605',
#  728: 'EXT_SOURCE_3 <= 0.015787 & DAYS_ID_PUBLISH > -4796.5 & DAYS_REGISTRATION <= -991.5',
#  729: 'EXT_SOURCE_3 <= 0.015787 & DAYS_ID_PUBLISH > -4796.5 & DAYS_REGISTRATION > -991.5',
#  730: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & OWN_CAR_AGE <= 15.0',
#  731: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & OWN_CAR_AGE > 15.0',
#  732: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 > 0.058627 & EXT_SOURCE_3 <= 0.155217',
#  733: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 > 0.058627 & EXT_SOURCE_3 > 0.155217',
#  734: 'NONLIVINGAREA_MODE <= 0.00115 & EXT_SOURCE_3 <= 0.660215 & EXT_SOURCE_1 <= 0.265393',
#  735: 'NONLIVINGAREA_MODE <= 0.00115 & EXT_SOURCE_3 <= 0.660215 & EXT_SOURCE_1 > 0.265393',
#  736: 'NONLIVINGAREA_MODE <= 0.00115 & EXT_SOURCE_3 > 0.660215 & COMMONAREA_MODE <= 0.29785',
#  737: 'NONLIVINGAREA_MODE <= 0.00115 & EXT_SOURCE_3 > 0.660215 & COMMONAREA_MODE > 0.29785',
#  738: 'NONLIVINGAREA_MODE > 0.00115 & AMT_INCOME_TOTAL <= 162225.0 & NAME_HOUSING_TYPE != House / apartment',
#  739: 'NONLIVINGAREA_MODE > 0.00115 & AMT_INCOME_TOTAL <= 162225.0 & NAME_HOUSING_TYPE == House / apartment',
#  740: 'NONLIVINGAREA_MODE > 0.00115 & AMT_INCOME_TOTAL > 162225.0 & EXT_SOURCE_2 <= 0.030775',
#  741: 'NONLIVINGAREA_MODE > 0.00115 & AMT_INCOME_TOTAL > 162225.0 & EXT_SOURCE_2 > 0.030775',
#  742: 'ORGANIZATION_TYPE != Industry: type 9 & OCCUPATION_TYPE != Security staff & DAYS_EMPLOYED <= -6782.5',
#  743: 'ORGANIZATION_TYPE != Industry: type 9 & OCCUPATION_TYPE != Security staff & DAYS_EMPLOYED > -6782.5',
#  744: 'ORGANIZATION_TYPE != Industry: type 9 & OCCUPATION_TYPE == Security staff & EXT_SOURCE_2 <= 0.236635',
#  745: 'ORGANIZATION_TYPE != Industry: type 9 & OCCUPATION_TYPE == Security staff & EXT_SOURCE_2 > 0.236635',
#  746: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 <= 0.235268 & HOUR_APPR_PROCESS_START <= 6.5',
#  747: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 <= 0.235268 & HOUR_APPR_PROCESS_START > 6.5',
#  748: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 > 0.235268 & AMT_REQ_CREDIT_BUREAU_DAY <= 0.5',
#  749: 'ORGANIZATION_TYPE == Industry: type 9 & EXT_SOURCE_2 > 0.235268 & AMT_REQ_CREDIT_BUREAU_DAY > 0.5',
#  750: 'DAYS_BIRTH <= -10419.5 & NAME_FAMILY_STATUS != Single / not married & DAYS_LAST_PHONE_CHANGE <= -1252.5',
#  751: 'DAYS_BIRTH <= -10419.5 & NAME_FAMILY_STATUS != Single / not married & DAYS_LAST_PHONE_CHANGE > -1252.5',
#  752: 'DAYS_BIRTH <= -10419.5 & NAME_FAMILY_STATUS == Single / not married & ORGANIZATION_TYPE != Legal Services',
#  753: 'DAYS_BIRTH <= -10419.5 & NAME_FAMILY_STATUS == Single / not married & ORGANIZATION_TYPE == Legal Services',
#  754: 'DAYS_BIRTH > -10419.5 & ORGANIZATION_TYPE != Transport: type 3 & EXT_SOURCE_2 <= 0.41659',
#  755: 'DAYS_BIRTH > -10419.5 & ORGANIZATION_TYPE != Transport: type 3 & EXT_SOURCE_2 > 0.41659',
#  756: 'DAYS_BIRTH > -10419.5 & ORGANIZATION_TYPE == Transport: type 3 & OBS_60_CNT_SOCIAL_CIRCLE <= 0.5',
#  757: 'DAYS_BIRTH > -10419.5 & ORGANIZATION_TYPE == Transport: type 3 & OBS_60_CNT_SOCIAL_CIRCLE > 0.5',
#  758: 'LIVINGAPARTMENTS_AVG <= 0.1507 & NAME_INCOME_TYPE != State servant & HOUR_APPR_PROCESS_START <= 7.5',
#  759: 'LIVINGAPARTMENTS_AVG <= 0.1507 & NAME_INCOME_TYPE != State servant & HOUR_APPR_PROCESS_START > 7.5',
#  760: 'LIVINGAPARTMENTS_AVG <= 0.1507 & NAME_INCOME_TYPE == State servant & NONLIVINGAPARTMENTS_MODE <= 0.18285',
#  761: 'LIVINGAPARTMENTS_AVG <= 0.1507 & NAME_INCOME_TYPE == State servant & NONLIVINGAPARTMENTS_MODE > 0.18285',
#  762: 'LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5 & HOUSETYPE_MODE != terraced house',
#  763: 'LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5 & HOUSETYPE_MODE == terraced house',
#  764: 'LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5 & YEARS_BUILD_MODE <= 0.8138',
#  765: 'LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5 & YEARS_BUILD_MODE > 0.8138',
#  766: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START != TUESDAY & AMT_REQ_CREDIT_BUREAU_YEAR <= 10.0',
#  767: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START != TUESDAY & AMT_REQ_CREDIT_BUREAU_YEAR > 10.0',
#  768: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START == TUESDAY & EXT_SOURCE_2 <= 0.035204',
#  769: 'EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START == TUESDAY & EXT_SOURCE_2 > 0.035204',
#  770: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & OCCUPATION_TYPE != Core staff',
#  771: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & OCCUPATION_TYPE == Core staff',
#  772: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 > 0.058627 & EXT_SOURCE_3 <= 0.155217',
#  773: 'EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 > 0.058627 & EXT_SOURCE_3 > 0.155217'}

# %%
def get_gbdt_feature(data, gbdt_path, cols_name=1):
    '''
    根据get_gbdt_path_var返回数据集的变量列表,回溯gbdt衍生给其他数据集:
    ------------------------------------------------------------
    入参结果如下:
        data: 需衍生变量的数据集,pd.DataFrame对象,不能有缺失
        gbdt_cols: get_gbdt_path返回的GBDT所有叶子节点的对应路径
        cols_name：是否使用GBDT路径作为列名,默认为1,传入0则将列名用叶子节点序号代替
    ------------------------------------------------------------
    出参结果如下:
        gbdt_feature: GBDT特征
    '''
    gbdt_feature = pd.DataFrame()

    # 遍历所有叶子节点经过的路径提取GBDT特征
    for key, value in gbdt_path.items():
        # 需执行exec的字符串开头
        if cols_name == 1:
            exec_str = "gbdt_feature['{}'] = ".format(value)
        elif cols_name == 0:
            exec_str = "gbdt_feature['{}'] = ".format(key)
        else:
            raise ValueError('请传入正确的cols_name参数,cols_name应为1或0')
            
        judge_len = len(value.split(' & '))

        # 遍历变量名中的所有条件加到exec字符串中
        for index, judge in enumerate(value.split(' & ')):
            # 数值型的条件
            if ('!=' not in judge) and ('==' not in judge):
                # 只有一个条件
                if judge_len == 1:
                    exec_str += ("(data['{}']{})".format(judge[: judge.find(' ')], judge[judge.find(' '):]))
                # 第一个条件
                elif index == 0:
                    exec_str += ("((data['{}']{})".format(judge[: judge.find(' ')], judge[judge.find(' '):]))
                # 最后一个条件
                elif index == judge_len - 1:
                    exec_str += (" & (data['{}']{}))".format(judge[: judge.find(' ')], judge[judge.find(' '):]))
                # 中间的条件
                else:
                    exec_str += (" & (data['{}']{})".format(judge[: judge.find(' ')], judge[judge.find(' '):]))
            # 字符型的条件
            else:
                if '==' in judge:
                    offset = 3
                else:
                    offset = 2
                # 只有一个条件
                if judge_len == 1:
                    exec_str += ("(data['{}']{}'{}')".format(judge[: judge.find(' ')],
                        judge[judge.find(' '): judge.find('=') + offset], judge[judge.find('=') + offset:]))
                # 第一个条件
                elif index == 0:
                    exec_str += ("((data['{}']{}'{}')".format(judge[: judge.find(' ')],
                        judge[judge.find(' '): judge.find('=') + offset], judge[judge.find('=') + offset:]))
                # 最后一个条件
                elif index == judge_len - 1:
                    exec_str += (" & (data['{}']{}'{}'))".format(judge[: judge.find(' ')], 
                        judge[judge.find(' '): judge.find('=') + offset], judge[judge.find('=') + offset:]))
                # 中间的条件
                else:
                    exec_str += (" & (data['{}']{}'{}')".format(judge[: judge.find(' ')], 
                        judge[judge.find(' '): judge.find('=') + offset], judge[judge.find('=') + offset:]))

        # 将True/False替换成1/0
        exec_str += ".astype(int)"
        
        exec(exec_str)

    return gbdt_feature

# %%
# 由于类别型的判断转换成了one-hot编码前的判断，可以用未经过one-hot编码的原数据集
train_gbdt_feature2 = get_gbdt_feature(X_train, gbdt_path)
train_gbdt_feature2.head()
# Out:
#        EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.36813 & EXT_SOURCE_2 <= 0.108422  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.36813 & EXT_SOURCE_2 > 0.108422  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 > 0.36813 & EXT_SOURCE_2 <= 0.137969  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 > 0.36813 & EXT_SOURCE_2 > 0.137969  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 <= 0.42325 & EXT_SOURCE_2 <= 0.597194  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  1
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 <= 0.42325 & EXT_SOURCE_2 > 0.597194  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  1
# 25479                                                  1
#
#        EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 > 0.42325 & EXT_SOURCE_2 <= 0.623373  \
# 53107                                                  1
# 42038                                                  1
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 > 0.356838 & EXT_SOURCE_3 > 0.42325 & EXT_SOURCE_2 > 0.623373  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.373177 & EXT_SOURCE_2 <= 0.106543  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_2 <= 0.356838 & EXT_SOURCE_3 <= 0.373177 & EXT_SOURCE_2 > 0.106543  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#                                               ...                                          \
# 53107                                         ...
# 42038                                         ...
# 48694                                         ...
# 39556                                         ...
# 25479                                         ...
#
#        LIVINGAPARTMENTS_AVG <= 0.1507 & NAME_INCOME_TYPE == State servant & NONLIVINGAPARTMENTS_MODE <= 0.18285  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        LIVINGAPARTMENTS_AVG <= 0.1507 & NAME_INCOME_TYPE == State servant & NONLIVINGAPARTMENTS_MODE > 0.18285  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5 & HOUSETYPE_MODE != terraced house  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  1
# 25479                                                  0
#
#        LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE <= 1.5 & HOUSETYPE_MODE == terraced house  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5 & YEARS_BUILD_MODE <= 0.8138  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        LIVINGAPARTMENTS_AVG > 0.1507 & DEF_60_CNT_SOCIAL_CIRCLE > 1.5 & YEARS_BUILD_MODE > 0.8138  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START != TUESDAY & AMT_REQ_CREDIT_BUREAU_YEAR <= 10.0  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  1
# 25479                                                  1
#
#        EXT_SOURCE_3 <= 0.015787 & WEEKDAY_APPR_PROCESS_START != TUESDAY & AMT_REQ_CREDIT_BUREAU_YEAR > 10.0  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & OCCUPATION_TYPE != Core staff  \
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
#        EXT_SOURCE_3 > 0.015787 & EXT_SOURCE_3 <= 0.058627 & OCCUPATION_TYPE == Core staff
# 53107                                                  0
# 42038                                                  0
# 48694                                                  0
# 39556                                                  0
# 25479                                                  0
#
# [5 rows x 745 columns]

# %%
print('模型的apply函数提取的GBDT特征维度', train_gbdt_feature1.shape)
print('解析树结构提取的GBDT特征维度', train_gbdt_feature2.shape)
# Out:
# 模型的apply函数提取的GBDT特征维度 (43051, 773)
# 解析树结构提取的GBDT特征维度 (43051, 745)

# %%
train_gbdt_feature3 = get_gbdt_feature(X_train, gbdt_path, cols_name=0)
test_gbdt_feature3 = get_gbdt_feature(X_test, gbdt_path, cols_name=0)

print('训练集：')
print('模型的apply函数提取的GBDT特征维度：', train_gbdt_feature1.shape)
print('解析树结构提取的GBDT特征维度：', train_gbdt_feature3.shape)
print('两个GBDT特征的所有值是否完全相等：', (train_gbdt_feature1 == np.array(train_gbdt_feature3)).all())

print('测试集：')
print('模型的apply函数提取的GBDT特征维度：', test_gbdt_feature1.shape)
print('解析树结构提取的GBDT特征维度：', test_gbdt_feature3.shape)
print('两个GBDT特征的所有值是否完全相等：', (test_gbdt_feature1 == np.array(test_gbdt_feature3)).all())
# Out:
# 训练集：
# 模型的apply函数提取的GBDT特征维度： (43051, 773)
# 解析树结构提取的GBDT特征维度： (43051, 773)
# 两个GBDT特征的所有值是否完全相等： True
# 测试集：
# 模型的apply函数提取的GBDT特征维度： (18451, 773)
# 解析树结构提取的GBDT特征维度： (18451, 773)
# 两个GBDT特征的所有值是否完全相等： False

# %%
test_gbdt_feature3.iloc[(test_gbdt_feature1 != np.array(test_gbdt_feature3)).sum(axis=1).astype(bool),
                        (test_gbdt_feature1 != np.array(test_gbdt_feature3)).sum(axis=0).astype(bool)]
# Out:
#        45  46
# 57072   0   1

# %%
test_gbdt_feature1[(test_gbdt_feature1 != np.array(test_gbdt_feature3)).sum(axis=1).astype(bool), 
                   (test_gbdt_feature1 != np.array(test_gbdt_feature3)).sum(axis=0).astype(bool)]
# Out:
# array([1., 0.])

# %%
gbdt_path[45]
# Out:
# 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.425012 & EXT_SOURCE_2 <= 0.591941'

# %%
gbdt_path[46]
# Out:
# 'EXT_SOURCE_2 > 0.247911 & EXT_SOURCE_3 <= 0.425012 & EXT_SOURCE_2 > 0.591941'

# %%
X_test.loc[57072, 'EXT_SOURCE_2']
# Out:
# 0.5919414304289855

# %%
gbdt_path4 = get_gbdt_path(model, data_cols, char_cols, precision=8)

test_gbdt_feature4 = get_gbdt_feature(X_test, gbdt_path4, cols_name=0)

print('测试集：')
print('模型的apply函数提取的GBDT特征维度：', test_gbdt_feature1.shape)
print('解析树结构提取的GBDT特征维度：', test_gbdt_feature4.shape)
print('两个GBDT特征的所有值是否完全相等：', (test_gbdt_feature1 == np.array(test_gbdt_feature4)).all())
# Out:
# 测试集：
# 模型的apply函数提取的GBDT特征维度： (18451, 773)
# 解析树结构提取的GBDT特征维度： (18451, 773)
# 两个GBDT特征的所有值是否完全相等： True

# %% [markdown]
# ## GBDT特征应用

# %%
# 每条规则的最多使用3个特征，每条规则最少覆盖10%的样本，并且生成的规则个数不超过400个
model_rule = GradientBoostingClassifier(max_depth=3, min_samples_leaf=0.1, n_estimators=50, random_state=1234)
model_rule.fit(X_train_new, y_train)

gbdt_rule = get_gbdt_path(model_rule, data_cols, char_cols, precision=8)

train_gbdt_rule = get_gbdt_feature(X_train, gbdt_rule)

rule_df = pd.DataFrame(columns=['rule', 'cover', 'target'], index=range(train_gbdt_rule.shape[1]))
rule_df['rule'] = train_gbdt_rule.columns
data_count = len(y_train)
rule_df['cover'] = [round((train_gbdt_rule[rule] == 1).sum() / data_count, 4)
                    for rule in train_gbdt_rule.columns]
rule_df['target'] = [round(y_train[train_gbdt_rule[rule] == 1].sum() / (train_gbdt_rule[rule] == 1).sum(), 4)
                     for rule in train_gbdt_rule.columns]

rule_df = rule_df.sort_values('target', ascending=False)
rule_df.index = range(rule_df.shape[0])

print('总样本目标为 1 的样本占比为: {:.2f}%\n'.format(100 * y_train.sum() / data_count))
print('根据目标占比,提取目标占比前 5 的规则,具体规则如下:')
for index in range(5):
    print('>> 规则 {}： 覆盖率 {:.2f}%  目标占比 {:.2f}%'.format(index + 1, 100 * rule_df.loc[index, 'cover'], 100 * rule_df.loc[index, 'target']))
    print('   {}\n'.format(rule_df.loc[index, 'rule']))
# Out:
# 总样本目标为 1 的样本占比为: 8.06%
#
# 根据目标占比,提取目标占比前 5 的规则,具体规则如下:
# >> 规则 1： 覆盖率 10.30%  目标占比 20.96%
#    EXT_SOURCE_2 <= 0.3568377 & EXT_SOURCE_3 <= 0.36812986
#
# >> 规则 2： 覆盖率 11.61%  目标占比 20.22%
#    EXT_SOURCE_3 <= 0.39019689 & EXT_SOURCE_2 <= 0.37501432
#
# >> 规则 3： 覆盖率 10.05%  目标占比 19.89%
#    EXT_SOURCE_1 <= 0.42324439 & DAYS_BIRTH > -19935.5 & EXT_SOURCE_2 <= 0.28651884
#
# >> 规则 4： 覆盖率 12.61%  目标占比 19.43%
#    EXT_SOURCE_2 <= 0.48394567 & EXT_SOURCE_3 <= 0.26575312
#
# >> 规则 5： 覆盖率 10.85%  目标占比 19.36%
#    EXT_SOURCE_3 <= 0.26434812 & EXT_SOURCE_3 > -0.49973637
